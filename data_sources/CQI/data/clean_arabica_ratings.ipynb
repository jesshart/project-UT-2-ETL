# %% [markdown]
# ## Clean up script for arabica_ratings_raw.
# Decisions arround data management will be recorded here.

# %%
# Dependencies
import pandas as pd
import numpy as np
import re

# %%
# Read CSV into pandas dataframe.
df = pd.read_csv('arabica_ratings_raw.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  quality_score  view_certificate_1  view_certificate_2  \
# 0           0          90.58                 NaN                 NaN
# 1           1          89.92                 NaN                 NaN
# 2           2          89.75                 NaN                 NaN
# 3           3          89.00                 NaN                 NaN
# 4           4          88.83                 NaN                 NaN
#
#    Cupping Protocol and Descriptors  View Green Analysis Details  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    Request a Sample  Species                     Owner Country of Origin  ...  \
# 0               NaN  Arabica                 metad plc          Ethiopia  ...
# 1               NaN  Arabica                 metad plc          Ethiopia  ...
# 2               NaN  Arabica  Grounds for Health Admin         Guatemala  ...
# 3               NaN  Arabica       Yidnekachew Dabessa          Ethiopia  ...
# 4               NaN  Arabica                 metad plc          Ethiopia  ...
#
#   Quakers  Color Category Two Defects NA.3        Expiration  \
# 0     0.0  Green       0 full defects  NaN   April 3rd, 2016
# 1     0.0  Green       1 full defects  NaN   April 3rd, 2016
# 2     0.0    NaN       0 full defects  NaN    May 31st, 2011
# 3     0.0  Green       2 full defects  NaN  March 25th, 2016
# 4     0.0  Green       2 full defects  NaN   April 3rd, 2016
#
#                    Certification Body  \
# 0  METAD Agricultural Development plc
# 1  METAD Agricultural Development plc
# 2        Specialty Coffee Association
# 3  METAD Agricultural Development plc
# 4  METAD Agricultural Development plc
#
#                                Certification Address  \
# 0  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 1  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 2        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 3  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 4  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
#
#                                Certification Contact  Unnamed: 51 Notes
# 0  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 1  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 2                        Chris Buck - (562) 624-4100          NaN   NaN
# 3  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 4  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
#
# [5 rows x 53 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# quality_score                       float64
# view_certificate_1                  float64
# view_certificate_2                  float64
# Cupping Protocol and Descriptors    float64
# View Green Analysis Details         float64
# Request a Sample                    float64
# Species                              object
# Owner                                object
# Country of Origin                    object
# Farm Name                            object
# Lot Number                           object
# Mill                                 object
# ICO Number                           object
# Company                              object
# Altitude                             object
# Region                               object
# Producer                             object
# Number of Bags                        int64
# Bag Weight                           object
# In-Country Partner                   object
# Harvest Year                         object
# Grading Date                         object
# Owner.1                              object
# Variety                              object
# Status                               object
# Processing Method                    object
# NA                                   object
# Aroma                               float64
# Flavor                              float64
# Aftertaste                          float64
# Acidity                             float64
# Body                                float64
# Balance                             float64
# NA.1                                 object
# Uniformity                          float64
# Clean Cup                           float64
# Sweetness                           float64
# Cupper Points                       float64
# Total Cup Points                     object
# NA.2                                float64
# Moisture                             object
# Category One Defects                 object
# Quakers                             float64
# Color                                object
# Category Two Defects                 object
# NA.3                                float64
# Expiration                           object
# Certification Body                   object
# Certification Address                object
# Certification Contact                object
# Unnamed: 51                         float64
# Notes                                object
# dtype: object

# %%
## Drop columns, view_certificate_1, view_certificate_2, Cupping Protocol and Descriptors, View Green Analysis Details, Request a Sample. No data

df1 = df.drop(columns =['view_certificate_1','view_certificate_2','Cupping Protocol and Descriptors','View Green Analysis Details','Request a Sample','NA.1','NA.2','NA.3'])

# %%
## Scan for N/A and convert to blank
## Count number of blanks per column 
df1=df1.replace('n/a',"",regex=True)
df1=df1.replace(np.nan,"",regex=True)

# %%
df1= df1.drop(columns =['Unnamed: 0'])

# %%
df1.index.name = 'ID'

# %%
## quality score convert to int
df1.astype({'quality_score':'int32'}).dtypes
# Out:
# quality_score              int32
# Species                   object
# Owner                     object
# Country of Origin         object
# Farm Name                 object
# Lot Number                object
# Mill                      object
# ICO Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number of Bags             int64
# Bag Weight                object
# In-Country Partner        object
# Harvest Year              object
# Grading Date              object
# Owner.1                   object
# Variety                   object
# Status                    object
# Processing Method         object
# NA                        object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean Cup                float64
# Sweetness                float64
# Cupper Points            float64
# Total Cup Points          object
# Moisture                  object
# Category One Defects      object
# Quakers                   object
# Color                     object
# Category Two Defects      object
# Expiration                object
# Certification Body        object
# Certification Address     object
# Certification Contact     object
# Unnamed: 51               object
# Notes                     object
# dtype: object

# %%
df2 = df1.copy()
df3 = df1.copy()

# %%
## remove lbs/kgs before counter
counter = -1
        
for row in df3['Bag Weight']:
   counter += 1
   if "kg" in row and "lbs" in row:
        df3.iloc[counter, 13] = ""

# %%
## list keeping track of cells with lbs for conversion later
counter = 0
idx_lst = []
for idx, row in enumerate(df3['Bag Weight']):
    if "lbs" in row:
        counter += 1

        idx_lst.append(idx)

# %%
counter = -1
        
for row in df2['Bag Weight']:
   counter += 1
   if "kg" in row and "lbs" in row: 
        df2.iloc[counter, 13] = 0

# %%
## Bag Weight convert to all kg. Drop all letters and make int
# if the cell has lbs and kg make the cell empty

counter = -1
        
for row in df2['Bag Weight']:
   counter += 1
   if row ==0:
       continue
   if "kg" in row:
        fixed = re.sub(r'[a-z]+','',row,re.I) 
        df2.iloc[counter, 13] = fixed
   if "lbs" in row:
        fixed= re.sub(r'[a-z]+','',row,re.I)
        df2.iloc[counter, 13] = fixed

# %%
#type conversion

df2['Bag Weight'] = df2['Bag Weight'].astype(int)

# %%
## convert lbs to kg
for i in idx_lst:
   df2.iloc[i,13]=df2.iloc[i,13]*.453592

# %%
df2.to_csv('testing.csv')

# %%
df2.dtypes
# Out:
# quality_score            float64
# Species                   object
# Owner                     object
# Country of Origin         object
# Farm Name                 object
# Lot Number                object
# Mill                      object
# ICO Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number of Bags             int64
# Bag Weight               float64
# In-Country Partner        object
# Harvest Year              object
# Grading Date              object
# Owner.1                   object
# Variety                   object
# Status                    object
# Processing Method         object
# NA                        object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean Cup                float64
# Sweetness                float64
# Cupper Points            float64
# Total Cup Points          object
# Moisture                  object
# Category One Defects      object
# Quakers                   object
# Color                     object
# Category Two Defects      object
# Expiration                object
# Certification Body        object
# Certification Address     object
# Certification Contact     object
# Unnamed: 51               object
# Notes                     object
# dtype: object

# %% [markdown]
# ## Altitude String Observations
#
# ### Observed
# 1. Since this data collects from bilingual participants, abbreviations differ.
#     - MSNM: Spanish — meters above sea level
#     - MASL: English — meters above sea level
#     - F: English — feet
#     - 公尺: Chinese — meter
# 2. There is the appearance of ranges (i.e. 640m-1400m).
#     - This is difficult because it requires making a decision about the data. Maybe we set the data for ranges in separate columns.
#
# ### Conclusions
# The majority of the data is in meters, so it will be our goal to convert all values to meters, therefore:
# 1. First, cleaned of any debris (non-values).
# 2. Second, the data must be sorted to find values that are not meters and convert them.
# 3. Third, the data must be split by lower and upper ranges.
#
# ### Results
# After printing using a for loop and if statements, it was discovered:
# <br>
#  - 'm' is present 360 times. <br>
#  - 'f' is present 26 times. <br>
#  - Otherwise, a number is present 700 times. <br>
#  - Garbage present 226 times. <br> <br>
#
# Total count: 1312 <br>
# Expected count: 1312

# %%
# Get length of index for reference
len_index = len(df2.index)

# %% [markdown]
# ## Cleaning Altitude Code
# The following code iterates over each element in 'Altitude' and checks it against some rules. Does it contain 'm' for meter, 'f' for foot, neither? Once checked, it appends a corrected string into a corresponding new column for replacement.

# %%
##Fix altitude data

# Function for checking string for number
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# Assign alt column to variable (as series)
alt = df2['Altitude']
count_y = 0
count_y_num = 0
count_y_f = 0
count_garb = 0

str_meter = []
str_feet = []
str_garb = []
str_num = []

# New column for appending
canon_col = []

for idx, elt in enumerate(alt):
    # if element contains m (suggesting meters)
    if 'm' in elt.lower() or '公尺' in elt.lower():
        count_y += 1
        
        ### --- Begin Canonincalizing --- ###
        elt_new = ""
        elt_garb = ""

        # Print for user
        print(f"""
        ---(String Conversion)---
        Working on [{elt}]
        -------------------------
        """)

        # Itertate over each character in a string
        for char in elt:

            # If character is numeric, add to new string in elt
            if char.isdigit() or "-" in char:
                elt_new += char

            # If not, add to garbage variable
            else:
                elt_garb += char

        elt_new = elt_new + " meters"

        print(f"""
        Digit result: {elt_new}
        Non-digit result: {elt_garb}
        """)

        # Append canon_col with new string
        canon_col.append(elt_new)

        ### --- End Canonicalizing --- ###
        
    # if not, it must be a different type
    else:
        
        # if element has numbers, what kind?
        if hasNumbers(elt):
            
            # are they feet?
            if 'f' in elt.lower():
                count_y_f += 1
                str_feet.append(elt)
                
                ### --- Begin Canonincalizing --- ###
                elt_new = ""
                elt_garb = ""

                # Print for user
                print(f"""
                ---(String Conversion)---
                Working on [{elt}]
                -------------------------
                """)

                # Itertate over each character in a string
                for char in elt:

                    # If character is numeric, add to new string in elt
                    if char.isdigit() or "-" in char:
                        elt_new += char

                    # If not, add to garbage variable
                    else:
                        elt_garb += char
                        
                elt_new = elt_new + " feet"

                print(f"""
                Digit result: {elt_new}
                Non-digit result: {elt_garb}
                """)
                
                # Append canon_col with new string
                canon_col.append(elt_new)
                
                ### --- End Canonicalizing --- ###
                
            # are they other?
            if 'f' not in elt.lower():
                count_y_num += 1
                
                ### --- Begin Canonincalizing --- ###
                elt_new = ""
                elt_garb = ""

                # Print for user
                print(f"""
                ---(String Conversion)---
                Working on [{elt}]
                -------------------------
                """)

                # Itertate over each character in a string
                for char in elt:

                    # If character is numeric, add to new string in elt
                    if char.isdigit() or "-" in char:
                        elt_new += char

                    # If not, add to garbage variable
                    else:
                        elt_garb += char
               
                # Try checking if value is metric
                try:
                    if int(elt_new) > 3937:
                        elt_new = elt_new + " feet"
                    else:
                        elt_new = elt_new + " meters"
                    print(f"""
                    Digit result: {elt_new}
                    Non-digit result: {elt_garb}
                    """)
                    
                # On values that error, add 'range'
                except:
                    elt_new = elt_new + " range"
                    print(f"!!! — Was not able to convert range: [{elt_new}]")

                
                # Append canon_col with new string
                canon_col.append(elt_new)
                
                ### --- End Canonicalizing --- ###
        else:
            count_garb += 1
            canon_col.append(elt)

q_sum = count_y+count_y_f+count_y_num+count_garb

if q_sum != len_index or len(canon_col) != len_index:
    print("ERROR")
else:
    print("----- SUCCESS -----")
            
print(f"""
Meters is present {count_y} times.
Feet is present {count_y_f} times.
Otherwise, number is present {count_y_num} times.
Garbage present {count_garb} times.
---
Process count: {count_y+count_y_f+count_y_num+count_garb}
Canon count (canon_col): {len(canon_col)}
Expected count: {len_index}
""")
# Out:
#                 ---(String Conversion)---
#                 Working on [1950-2200]
#                 -------------------------
#
# !!! — Was not able to convert range: [1950-2200 range]
#
#                 ---(String Conversion)---
#                 Working on [1950-2200]
#                 -------------------------
#
# !!! — Was not able to convert range: [1950-2200 range]
#
#         ---(String Conversion)---
#         Working on [1600 - 1800 m]
#         -------------------------
#
#
#         Digit result: 1600-1800 meters
#         Non-digit result:    m
#
#
#                 ---(String Conversion)---
#                 Working on [1800-2200]
#                 -------------------------
#
# !!! — Was not able to convert range: [1800-2200 range]
#
#                 ---(String Conversion)---
#                 Working on [1950-2200]
#                 -------------------------
#
# !!! — Was not able to convert range: [1950-2200 range]
#
#                 ---(String Conversion)---
#                 Working on [1570-1700]
#                 -------------------------
#
# !!! — Was not able to convert range: [1570-1700 range]
#
#                 ---(String Conversion)---
#                 Working on [1570-1700]
#                 -------------------------
#
# !!! — Was not able to convert range: [1570-1700 range]
#
#                 ---(String Conversion)---
#                 Working on [1795-1850]
#                 -------------------------
#
# !!! — Was not able to convert range: [1795-1850 range]
#
#                 ---(String Conversion)---
#                 Working on [1855-1955]
#                 -------------------------
#
# !!! — Was not able to convert range: [1855-1955 range]
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 1.872]
#         -------------------------
#
#
#         Digit result: 1872 meters
#         Non-digit result: Meters above sea level: .
#
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 1.943]
#         -------------------------
#
#
#         Digit result: 1943 meters
#         Non-digit result: Meters above sea level: .
#
#
#                 ---(String Conversion)---
#                 Working on [2000 ft]
#                 -------------------------
#
#
#                 Digit result: 2000 feet
#                 Non-digit result:  ft
#
#
#                 ---(String Conversion)---
#                 Working on [1570-1700]
#                 -------------------------
#
# !!! — Was not able to convert range: [1570-1700 range]
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 2.080]
#         -------------------------
#
#
#         Digit result: 2080 meters
#         Non-digit result: Meters above sea level: .
#
#
#         ---(String Conversion)---
#         Working on [1200-1800m]
#         -------------------------
#
#
#         Digit result: 1200-1800 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1450]
#                 -------------------------
#
#
#                     Digit result: 1450 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1700-2000m]
#         -------------------------
#
#
#         Digit result: 1700-2000 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 2.019]
#         -------------------------
#
#
#         Digit result: 2019 meters
#         Non-digit result: Meters above sea level: .
#
#
#         ---(String Conversion)---
#         Working on [1300 MSNM]
#         -------------------------
#
#
#         Digit result: 1300 meters
#         Non-digit result:  MSNM
#
#
#                 ---(String Conversion)---
#                 Working on [1320]
#                 -------------------------
#
#
#                     Digit result: 1320 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 2.112]
#         -------------------------
#
#
#         Digit result: 2112 meters
#         Non-digit result: Meters above sea level: .
#
#
#         ---(String Conversion)---
#         Working on [1250m]
#         -------------------------
#
#
#         Digit result: 1250 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1950]
#                 -------------------------
#
#
#                     Digit result: 1950 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1750-1800]
#                 -------------------------
#
# !!! — Was not able to convert range: [1750-1800 range]
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [Meters above sea level: 1.941]
#         -------------------------
#
#
#         Digit result: 1941 meters
#         Non-digit result: Meters above sea level: .
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1.2]
#                 -------------------------
#
#
#                     Digit result: 12 meters
#                     Non-digit result: .
#
#
#                 ---(String Conversion)---
#                 Working on [1.2]
#                 -------------------------
#
#
#                     Digit result: 12 meters
#                     Non-digit result: .
#
#
#         ---(String Conversion)---
#         Working on [1000 M]
#         -------------------------
#
#
#         Digit result: 1000 meters
#         Non-digit result:  M
#
#
#                 ---(String Conversion)---
#                 Working on [1754]
#                 -------------------------
#
#
#                     Digit result: 1754 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1250m]
#         -------------------------
#
#
#         Digit result: 1250 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [900-1,500m]
#         -------------------------
#
#
#         Digit result: 900-1500 meters
#         Non-digit result: ,m
#
#
#         ---(String Conversion)---
#         Working on [1520m-2200m]
#         -------------------------
#
#
#         Digit result: 1520-2200 meters
#         Non-digit result: mm
#
#
#         ---(String Conversion)---
#         Working on [1400-1900M]
#         -------------------------
#
#
#         Digit result: 1400-1900 meters
#         Non-digit result: M
#
#
#         ---(String Conversion)---
#         Working on [1500-2000 m]
#         -------------------------
#
#
#         Digit result: 1500-2000 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1400ft]
#                 -------------------------
#
#
#                 Digit result: 1400 feet
#                 Non-digit result: ft
#
#
#                 ---(String Conversion)---
#                 Working on [1400-1900]
#                 -------------------------
#
# !!! — Was not able to convert range: [1400-1900 range]
#
#         ---(String Conversion)---
#         Working on [1800 msnm]
#         -------------------------
#
#
#         Digit result: 1800 meters
#         Non-digit result:  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1600]
#                 -------------------------
#
#
#                     Digit result: 1600 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1800-2000]
#                 -------------------------
#
# !!! — Was not able to convert range: [1800-2000 range]
#
#                 ---(String Conversion)---
#                 Working on [5000]
#                 -------------------------
#
#
#                     Digit result: 5000 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4650]
#                 -------------------------
#
#
#                     Digit result: 4650 feet
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1,700 mts]
#         -------------------------
#
#
#         Digit result: 1700 meters
#         Non-digit result: , mts
#
#
#         ---(String Conversion)---
#         Working on [1500 meters]
#         -------------------------
#
#
#         Digit result: 1500 meters
#         Non-digit result:  meters
#
#
#         ---(String Conversion)---
#         Working on [1300~1400 m.s.l]
#         -------------------------
#
#
#         Digit result: 13001400 meters
#         Non-digit result: ~ m.s.l
#
#
#                 ---(String Conversion)---
#                 Working on [1680]
#                 -------------------------
#
#
#                     Digit result: 1680 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1900M]
#         -------------------------
#
#
#         Digit result: 1900 meters
#         Non-digit result: M
#
#
#                 ---(String Conversion)---
#                 Working on [1800-2000]
#                 -------------------------
#
# !!! — Was not able to convert range: [1800-2000 range]
#
#                 ---(String Conversion)---
#                 Working on [1600]
#                 -------------------------
#
#
#                     Digit result: 1600 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [5600-5760 METROS]
#         -------------------------
#
#
#         Digit result: 5600-5760 meters
#         Non-digit result:  METROS
#
#
#                 ---(String Conversion)---
#                 Working on [1800-2000]
#                 -------------------------
#
# !!! — Was not able to convert range: [1800-2000 range]
#
#                 ---(String Conversion)---
#                 Working on [1950]
#                 -------------------------
#
#
#                     Digit result: 1950 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1250m]
#         -------------------------
#
#
#         Digit result: 1250 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [1400 M]
#         -------------------------
#
#
#         Digit result: 1400 meters
#         Non-digit result:  M
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1770]
#                 -------------------------
#
#
#                     Digit result: 1770 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1300 msnm]
#         -------------------------
#
#
#         Digit result: 1300 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [above 1600 M]
#         -------------------------
#
#
#         Digit result: 1600 meters
#         Non-digit result: above  M
#
#
#         ---(String Conversion)---
#         Working on [Above 1200 M]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result: Above  M
#
#
#         ---(String Conversion)---
#         Working on [1550 msnm]
#         -------------------------
#
#
#         Digit result: 1550 meters
#         Non-digit result:  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1550]
#                 -------------------------
#
#
#                     Digit result: 1550 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1250-1400 meter]
#         -------------------------
#
#
#         Digit result: 1250-1400 meters
#         Non-digit result:  meter
#
#
#         ---(String Conversion)---
#         Working on [1400 msm]
#         -------------------------
#
#
#         Digit result: 1400 meters
#         Non-digit result:  msm
#
#
#         ---(String Conversion)---
#         Working on [2.560 msnm]
#         -------------------------
#
#
#         Digit result: 2560 meters
#         Non-digit result: . msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [2136 msnm]
#         -------------------------
#
#
#         Digit result: 2136 meters
#         Non-digit result:  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1900]
#                 -------------------------
#
#
#                     Digit result: 1900 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [-1]
#                 -------------------------
#
#
#                     Digit result: -1 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1580]
#                 -------------------------
#
#
#                     Digit result: 1580 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1100m]
#         -------------------------
#
#
#         Digit result: 1100 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [1400 MASL]
#         -------------------------
#
#
#         Digit result: 1400 meters
#         Non-digit result:  MASL
#
#
#                 ---(String Conversion)---
#                 Working on [3500-5200 feet]
#                 -------------------------
#
#
#                 Digit result: 3500-5200 feet
#                 Non-digit result:  feet
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [800 M]
#         -------------------------
#
#
#         Digit result: 800 meters
#         Non-digit result:  M
#
#
#         ---(String Conversion)---
#         Working on [1620M]
#         -------------------------
#
#
#         Digit result: 1620 meters
#         Non-digit result: M
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1200m]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [1000 m]
#         -------------------------
#
#
#         Digit result: 1000 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [350]
#                 -------------------------
#
#
#                     Digit result: 350 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400-1900]
#                 -------------------------
#
# !!! — Was not able to convert range: [1400-1900 range]
#
#         ---(String Conversion)---
#         Working on [1500-2000 m]
#         -------------------------
#
#
#         Digit result: 1500-2000 meters
#         Non-digit result:  m
#
#
#         ---(String Conversion)---
#         Working on [1500-2000 m]
#         -------------------------
#
#
#         Digit result: 1500-2000 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1450 msnm]
#         -------------------------
#
#
#         Digit result: 1450 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1200 mts]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result:  mts
#
#
#         ---(String Conversion)---
#         Working on [800-1050m]
#         -------------------------
#
#
#         Digit result: 800-1050 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [170]
#                 -------------------------
#
#
#                     Digit result: 170 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1150]
#                 -------------------------
#
#
#                     Digit result: 1150 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1600]
#                 -------------------------
#
#
#                     Digit result: 1600 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1750]
#                 -------------------------
#
#
#                     Digit result: 1750 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1900M]
#         -------------------------
#
#
#         Digit result: 1900 meters
#         Non-digit result: M
#
#
#         ---(String Conversion)---
#         Working on [1750M]
#         -------------------------
#
#
#         Digit result: 1750 meters
#         Non-digit result: M
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1000 M]
#         -------------------------
#
#
#         Digit result: 1000 meters
#         Non-digit result:  M
#
#
#                 ---(String Conversion)---
#                 Working on [1550]
#                 -------------------------
#
#
#                     Digit result: 1550 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [2000]
#                 -------------------------
#
#
#                     Digit result: 2000 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [5000]
#                 -------------------------
#
#
#                     Digit result: 5000 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1700-1850m]
#         -------------------------
#
#
#         Digit result: 1700-1850 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [1500-2000 m]
#         -------------------------
#
#
#         Digit result: 1500-2000 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1754]
#                 -------------------------
#
#
#                     Digit result: 1754 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [5000 FT.]
#                 -------------------------
#
#
#                 Digit result: 5000 feet
#                 Non-digit result:  FT.
#
#
#                 ---(String Conversion)---
#                 Working on [4000 PSN]
#                 -------------------------
#
#
#                     Digit result: 4000 feet
#                     Non-digit result:  PSN
#
#
#                 ---(String Conversion)---
#                 Working on [1550]
#                 -------------------------
#
#
#                     Digit result: 1550 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1600 a 1900 msnm]
#         -------------------------
#
#
#         Digit result: 16001900 meters
#         Non-digit result:  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [1750 msnm]
#         -------------------------
#
#
#         Digit result: 1750 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1450 ~ 1700 m]
#         -------------------------
#
#
#         Digit result: 14501700 meters
#         Non-digit result:  ~  m
#
#
#         ---(String Conversion)---
#         Working on [1800 msnm]
#         -------------------------
#
#
#         Digit result: 1800 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1300m]
#         -------------------------
#
#
#         Digit result: 1300 meters
#         Non-digit result: m
#
#
#         ---(String Conversion)---
#         Working on [1100m]
#         -------------------------
#
#
#         Digit result: 1100 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1750]
#                 -------------------------
#
#
#                     Digit result: 1750 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1680]
#                 -------------------------
#
#
#                     Digit result: 1680 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [Above 1100m]
#         -------------------------
#
#
#         Digit result: 1100 meters
#         Non-digit result: Above m
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [2000 m]
#         -------------------------
#
#
#         Digit result: 2000 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [mmm]
#         -------------------------
#
#
#         Digit result:  meters
#         Non-digit result: mmm
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [1200M]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result: M
#
#
#                 ---(String Conversion)---
#                 Working on [900]
#                 -------------------------
#
#
#                     Digit result: 900 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [442 msnm]
#         -------------------------
#
#
#         Digit result: 442 meters
#         Non-digit result:  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1200m to 1350m]
#         -------------------------
#
#
#         Digit result: 12001350 meters
#         Non-digit result: m to m
#
#
#         ---(String Conversion)---
#         Working on [900-1200m]
#         -------------------------
#
#
#         Digit result: 900-1200 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [3600-6200 ft]
#                 -------------------------
#
#
#                 Digit result: 3600-6200 feet
#                 Non-digit result:  ft
#
#
#                 ---(String Conversion)---
#                 Working on [4400-4700 ft]
#                 -------------------------
#
#
#                 Digit result: 4400-4700 feet
#                 Non-digit result:  ft
#
#
#                 ---(String Conversion)---
#                 Working on [1000]
#                 -------------------------
#
#
#                     Digit result: 1000 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [2560]
#                 -------------------------
#
#
#                     Digit result: 2560 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [3607]
#                 -------------------------
#
#
#                     Digit result: 3607 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [442 msnm]
#         -------------------------
#
#
#         Digit result: 442 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1620M]
#         -------------------------
#
#
#         Digit result: 1620 meters
#         Non-digit result: M
#
#
#                 ---(String Conversion)---
#                 Working on [1600]
#                 -------------------------
#
#
#                     Digit result: 1600 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 PSNM]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  PSNM
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1450]
#                 -------------------------
#
#
#                     Digit result: 1450 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1170]
#                 -------------------------
#
#
#                     Digit result: 1170 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1700m]
#         -------------------------
#
#
#         Digit result: 1700 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [3664]
#                 -------------------------
#
#
#                     Digit result: 3664 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1565]
#                 -------------------------
#
#
#                     Digit result: 1565 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [3280]
#                 -------------------------
#
#
#                     Digit result: 3280 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [de 900 a 1100 msnm]
#         -------------------------
#
#
#         Digit result: 9001100 meters
#         Non-digit result: de  a  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1150]
#                 -------------------------
#
#
#                     Digit result: 1150 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1850]
#                 -------------------------
#
#
#                     Digit result: 1850 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1545-1668 MASL]
#         -------------------------
#
#
#         Digit result: 1545-1668 meters
#         Non-digit result:  MASL
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1530]
#                 -------------------------
#
#
#                     Digit result: 1530 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [approx. 1'500 metres a.s.l.]
#         -------------------------
#
#
#         Digit result: 1500 meters
#         Non-digit result: approx. ' metres a.s.l.
#
#
#         ---(String Conversion)---
#         Working on  - 1183m]
#         -------------------------
#
#
#         Digit result: 894-1183 meters
#         Non-digit result: m  m
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1500 meters]
#         -------------------------
#
#
#         Digit result: 1500 meters
#         Non-digit result:  meters
#
#
#         ---(String Conversion)---
#         Working on [1750 msnm]
#         -------------------------
#
#
#         Digit result: 1750 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1500-1700m]
#         -------------------------
#
#
#         Digit result: 1500-1700 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [442]
#                 -------------------------
#
#
#                     Digit result: 442 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [968]
#                 -------------------------
#
#
#                     Digit result: 968 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [1550]
#                 -------------------------
#
#
#                     Digit result: 1550 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1480]
#                 -------------------------
#
#
#                     Digit result: 1480 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1800m]
#         -------------------------
#
#
#         Digit result: 1800 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [5440 - 5760 METROS]
#         -------------------------
#
#
#         Digit result: 5440-5760 meters
#         Non-digit result:    METROS
#
#
#                 ---(String Conversion)---
#                 Working on [1600]
#                 -------------------------
#
#
#                     Digit result: 1600 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 PSNM]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  PSNM
#
#
#         ---(String Conversion)---
#         Working on [4000 PSNM]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  PSNM
#
#
#                 ---(String Conversion)---
#                 Working on [1480]
#                 -------------------------
#
#
#                     Digit result: 1480 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1450]
#                 -------------------------
#
#
#                     Digit result: 1450 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [1550 m]
#         -------------------------
#
#
#         Digit result: 1550 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1260]
#                 -------------------------
#
#
#                     Digit result: 1260 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1700 msnm]
#         -------------------------
#
#
#         Digit result: 1700 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [Above 1200 M]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result: Above  M
#
#
#                 ---(String Conversion)---
#                 Working on [1650]
#                 -------------------------
#
#
#                     Digit result: 1650 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1700m]
#         -------------------------
#
#
#         Digit result: 1700 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [890]
#                 -------------------------
#
#
#                     Digit result: 890 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [934]
#                 -------------------------
#
#
#                     Digit result: 934 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [442]
#                 -------------------------
#
#
#                     Digit result: 442 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [De 1600 a 1950 msnm]
#         -------------------------
#
#
#         Digit result: 16001950 meters
#         Non-digit result: De  a  msnm
#
#
#         ---(String Conversion)---
#         Working on [950公尺]
#         -------------------------
#
#
#         Digit result: 950 meters
#         Non-digit result: 公尺
#
#
#                 ---(String Conversion)---
#                 Working on [1550]
#                 -------------------------
#
#
#                     Digit result: 1550 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [900]
#                 -------------------------
#
#
#                     Digit result: 900 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [2527]
#                 -------------------------
#
#
#                     Digit result: 2527 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1850]
#                 -------------------------
# ...
#                 Working on [1850]
#                 -------------------------
#
#
#                     Digit result: 1850 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1150]
#                 -------------------------
#
#
#                     Digit result: 1150 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 PSNM]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  PSNM
#
#
#         ---(String Conversion)---
#         Working on [800M]
#         -------------------------
#
#
#         Digit result: 800 meters
#         Non-digit result: M
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1,600 meters]
#         -------------------------
#
#
#         Digit result: 1600 meters
#         Non-digit result: , meters
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 P.S.N.M]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  P.S.N.M
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1050]
#                 -------------------------
#
#
#                     Digit result: 1050 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [650]
#                 -------------------------
#
#
#                     Digit result: 650 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 P.S.N.M]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  P.S.N.M
#
#
#         ---(String Conversion)---
#         Working on [1200 meters]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result:  meters
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [850]
#                 -------------------------
#
#
#                     Digit result: 850 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1200 msm]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result:  msm
#
#
#                 ---(String Conversion)---
#                 Working on [1248]
#                 -------------------------
#
#
#                     Digit result: 1248 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1000]
#                 -------------------------
#
#
#                     Digit result: 1000 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [750-800 M]
#         -------------------------
#
#
#         Digit result: 750-800 meters
#         Non-digit result:  M
#
#
#                 ---(String Conversion)---
#                 Working on [1300]
#                 -------------------------
#
#
#                     Digit result: 1300 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [890]
#                 -------------------------
#
#
#                     Digit result: 890 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [4000 P.S.N.M.]
#         -------------------------
#
#
#         Digit result: 4000 meters
#         Non-digit result:  P.S.N.M.
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [400-1250m]
#         -------------------------
#
#
#         Digit result: 400-1250 meters
#         Non-digit result: m
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [900-1500 masl]
#         -------------------------
#
#
#         Digit result: 900-1500 meters
#         Non-digit result:  masl
#
#
#         ---(String Conversion)---
#         Working on [1200 m]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result:  m
#
#
#                 ---(String Conversion)---
#                 Working on [1100]
#                 -------------------------
#
#
#                     Digit result: 1100 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [3500]
#                 -------------------------
#
#
#                     Digit result: 3500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1250]
#                 -------------------------
#
#
#                     Digit result: 1250 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1000+ meters]
#         -------------------------
#
#
#         Digit result: 1000 meters
#         Non-digit result: + meters
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1100]
#                 -------------------------
#
#
#                     Digit result: 1100 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1100]
#                 -------------------------
#
#
#                     Digit result: 1100 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1280]
#                 -------------------------
#
#
#                     Digit result: 1280 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [850]
#                 -------------------------
#
#
#                     Digit result: 850 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1500]
#                 -------------------------
#
#
#                     Digit result: 1500 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1250]
#                 -------------------------
#
#
#                     Digit result: 1250 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1700]
#                 -------------------------
#
#
#                     Digit result: 1700 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4300]
#                 -------------------------
#
#
#                     Digit result: 4300 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1140]
#                 -------------------------
#
#
#                     Digit result: 1140 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1200]
#                 -------------------------
#
#
#                     Digit result: 1200 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1250]
#                 -------------------------
#
#
#                     Digit result: 1250 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1350]
#                 -------------------------
#
#
#                     Digit result: 1350 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1,200 meters]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result: , meters
#
#
#         ---(String Conversion)---
#         Working on -1400m]
#         -------------------------
#
#
#         Digit result: 640-1400 meters
#         Non-digit result: mm
#
#
#         ---(String Conversion)---
#         Working on [1200 msm]
#         -------------------------
#
#
#         Digit result: 1200 meters
#         Non-digit result:  msm
#
#
#                 ---(String Conversion)---
#                 Working on [800]
#                 -------------------------
#
#
#                     Digit result: 800 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1800]
#                 -------------------------
#
#
#                     Digit result: 1800 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [1,000 meters]
#         -------------------------
#
#
#         Digit result: 1000 meters
#         Non-digit result: , meters
#
#
#         ---(String Conversion)---
#         Working on [1450 msnm]
#         -------------------------
#
#
#         Digit result: 1450 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1450 msnm]
#         -------------------------
#
#
#         Digit result: 1450 meters
#         Non-digit result:  msnm
#
#
#         ---(String Conversion)---
#         Working on [1450 msnm]
#         -------------------------
#
#
#         Digit result: 1450 meters
#         Non-digit result:  msnm
#
#
#                 ---(String Conversion)---
#                 Working on [900]
#                 -------------------------
#
#
#                     Digit result: 900 meters
#                     Non-digit result:
#
#
#         ---(String Conversion)---
#         Working on [~350m]
#         -------------------------
#
#
#         Digit result: 350 meters
#         Non-digit result: ~m
#
#
#                 ---(String Conversion)---
#                 Working on [1100]
#                 -------------------------
#
#
#                     Digit result: 1100 meters
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [4650]
#                 -------------------------
#
#
#                     Digit result: 4650 feet
#                     Non-digit result:
#
#
#                 ---(String Conversion)---
#                 Working on [1400]
#                 -------------------------
#
#
#                     Digit result: 1400 meters
#                     Non-digit result:
#
# ----- SUCCESS -----
#
# Meters is present 360 times.
# Feet is present 26 times.
# Otherwise, number is present 700 times.
# Garbage present 226 times.
# ---
# Process count: 1312
# Canon count (canon_col): 1312
# Expected count: 1312

# %%
canon_col
# Out:
# ['1950-2200 range',
#  '1950-2200 range',
#  '1600-1800 meters',
#  '1800-2200 range',
#  '1950-2200 range',
#  '',
#  '',
#  '1570-1700 range',
#  '1570-1700 range',
#  '1795-1850 range',
#  '1855-1955 range',
#  '1872 meters',
#  '1943 meters',
#  '2000 feet',
#  '1570-1700 range',
#  '2080 meters',
#  '1200-1800 meters',
#  '',
#  '1450 meters',
#  '1700-2000 meters',
#  '2019 meters',
#  '1300 meters',
#  '1320 meters',
#  '2112 meters',
#  '',
#  '1250 meters',
#  '',
#  '1950 meters',
#  '1400 meters',
#  '1200 meters',
#  '',
#  '',
#  '1300 meters',
#  '1300 meters',
#  '1750-1800 range',
#  '1800 meters',
#  '',
#  '',
#  '',
#  '1941 meters',
#  '1300 meters',
#  '12 meters',
#  '12 meters',
#  '1000 meters',
#  '1754 meters',
#  '1250 meters',
#  '',
#  '900-1500 meters',
#  '1520-2200 meters',
#  '1400-1900 meters',
#  '1500-2000 meters',
#  '1400 feet',
#  '',
#  '1400-1900 range',
#  '1800 meters',
#  '1600 meters',
#  '1800-2000 range',
#  '5000 feet',
#  '4650 feet',
#  '',
#  '',
#  '1700 meters',
#  '1500 meters',
#  '13001400 meters',
#  '',
#  '1680 meters',
#  '1900 meters',
#  '1800-2000 range',
#  '1600 meters',
#  '5600-5760 meters',
#  '1800-2000 range',
#  '1950 meters',
#  '',
#  '1250 meters',
#  '1400 meters',
#  '1700 meters',
#  '1770 meters',
#  '1300 meters',
#  '1300 meters',
#  '1600 meters',
#  '1200 meters',
#  '',
#  '',
#  '',
#  '1550 meters',
#  '1550 meters',
#  '1250-1400 meters',
#  '1400 meters',
#  '',
#  '2560 meters',
#  '1700 meters',
#  '',
#  '2136 meters',
#  '',
#  '',
#  '',
#  '1800 meters',
#  '',
#  '1900 meters',
#  '1300 meters',
#  '-1 meters',
#  '1580 meters',
#  '1100 meters',
#  '1400 meters',
#  '',
#  '3500-5200 feet',
#  '',
#  '16001950 meters',
#  '800 meters',
#  '1620 meters',
#  '16001950 meters',
#  '1200 meters',
#  '1200 meters',
#  '1000 meters',
#  '',
#  '350 meters',
#  '1400-1900 range',
#  '',
#  '1500-2000 meters',
#  '1500-2000 meters',
#  '',
#  '1800 meters',
#  '1450 meters',
#  '1200 meters',
#  '800-1050 meters',
#  '1350 meters',
#  '1200 meters',
#  '170 meters',
#  '1150 meters',
#  '1600 meters',
#  '1750 meters',
#  '1900 meters',
#  '1750 meters',
#  '1200 meters',
#  '',
#  '1000 meters',
#  '1550 meters',
#  '2000 meters',
#  '4300 feet',
#  '5000 feet',
#  '1200 meters',
#  '1700-1850 meters',
#  '',
#  '1500-2000 meters',
#  '1754 meters',
#  '1500 meters',
#  '',
#  '1800 meters',
#  '5000 feet',
#  '4000 feet',
#  '1550 meters',
#  '16001900 meters',
#  '',
#  '1750 meters',
#  '14501700 meters',
#  '1800 meters',
#  '1300 meters',
#  '1100 meters',
#  '1200 meters',
#  '1750 meters',
#  '1680 meters',
#  '1700 meters',
#  '1800 meters',
#  '1100 meters',
#  '4300 feet',
#  '2000 meters',
#  '1350 meters',
#  '1500 meters',
#  '',
#  ' meters',
#  'TEST',
#  '1300 meters',
#  '1400 meters',
#  '',
#  '16001950 meters',
#  '1200 meters',
#  '',
#  '900 meters',
#  '',
#  '1800 meters',
#  '1500 meters',
#  '',
#  '1500 meters',
#  '',
#  '442 meters',
#  '1800 meters',
#  '1700 meters',
#  '12001350 meters',
#  '900-1200 meters',
#  '3600-6200 feet',
#  '4400-4700 feet',
#  '1000 meters',
#  '1200 meters',
#  '2560 meters',
#  '1500 meters',
#  '3607 meters',
#  '1400 meters',
#  '16001950 meters',
#  '16001950 meters',
#  '1800 meters',
#  '442 meters',
#  '1620 meters',
#  '1600 meters',
#  '4000 meters',
#  '1700 meters',
#  '',
#  '1450 meters',
#  '1170 meters',
#  '1400 meters',
#  '1700 meters',
#  '1700 meters',
#  '',
#  '1700 meters',
#  '3664 meters',
#  '1565 meters',
#  '3280 meters',
#  '16001950 meters',
#  '9001100 meters',
#  '1150 meters',
#  '1850 meters',
#  '1545-1668 meters',
#  '1400 meters',
#  '1530 meters',
#  '',
#  '1500 meters',
#  '894-1183 meters',
#  '4300 feet',
#  '1500 meters',
#  '1750 meters',
#  '',
#  '1500-1700 meters',
#  '',
#  '442 meters',
#  '968 meters',
#  '',
#  '16001950 meters',
#  '1550 meters',
#  '',
#  '1480 meters',
#  '1800 meters',
#  '',
#  '1800 meters',
#  '1500 meters',
#  '5440-5760 meters',
#  '1600 meters',
#  '4000 meters',
#  '4000 meters',
#  '1480 meters',
#  '1450 meters',
#  '16001950 meters',
#  '1550 meters',
#  '1260 meters',
#  '1700 meters',
#  '1200 meters',
#  '-',
#  '1650 meters',
#  '1700 meters',
#  '',
#  '890 meters',
#  '1300 meters',
#  '1350 meters',
#  '934 meters',
#  '1200 meters',
#  '442 meters',
#  '',
#  'none',
#  '',
#  '',
#  '16001950 meters',
#  '950 meters',
#  '1550 meters',
#  '900 meters',
#  '1500 meters',
#  '1400 meters',
#  '2527 meters',
#  '',
#  '1850 meters',
#  '1500 meters',
#  '1200 meters',
#  '1 meters',
#  '480-570 meters',
#  '1650-1703 range',
#  '1200 meters',
#  '1200-1400 range',
#  '4000 meters',
#  '1260 meters',
#  '800 meters',
#  '1750 meters',
#  '4300 feet',
#  '1218 meters',
#  '1300 meters',
#  '1250 meters',
#  '4921 feet',
#  '',
#  '',
#  '1800 meters',
#  '890 meters',
#  '442 meters',
#  '750 meters',
#  '',
#  '1650 meters',
#  '442 meters',
#  '1400 meters',
#  '2800 feet',
#  '16001950 meters',
#  '1500-1600 range',
#  '1750 meters',
#  '1750 meters',
#  '',
#  '700 meters',
#  '1300 meters',
#  '1600 meters',
#  '1600 meters',
#  '',
#  '890 meters',
#  '1700 meters',
#  '1400 meters',
#  '1250 meters',
#  '934 meters',
#  '1200 meters',
#  '1350 meters',
#  '800 meters',
#  '1550-1700 meters',
#  '4451 meters',
#  '1750 meters',
#  '1800-2000 range',
#  '4300 feet',
#  '4300 feet',
#  '1750 meters',
#  '1450 meters',
#  '4300 feet',
#  '1100 meters',
#  '1200-1600 meters',
#  '5000 feet',
#  '',
#  '890 meters',
#  '3702 meters',
#  '',
#  '1100 meters',
#  '16001950 meters',
#  '1200 meters',
#  '1700-2000 meters',
#  '1800 meters',
#  '1600 meters',
#  '1550 meters',
#  '1550 meters',
#  '1000 meters',
#  '16001950 meters',
#  '1000 meters',
#  '2136 meters',
#  '1100 meters',
#  '1799 meters',
#  '',
#  '1850 meters',
#  '1000 meters',
#  '4000 feet',
#  '16001950 meters',
#  '1400 meters',
#  '1500 meters',
#  '1600 meters',
#  '',
#  '1850 meters',
#  '1400 meters',
#  '1650 meters',
#  '1350 meters',
#  '1750 meters',
#  '1750 meters',
#  '1170 meters',
#  '940 meters',
#  '1400 meters',
#  '5000 feet',
#  '16001950 meters',
#  '4600 feet',
#  '',
#  '1600 meters',
#  '439 meters',
#  '1700 meters',
#  '442 meters',
#  '1850 meters',
#  '',
#  '1800 meters',
#  '1200 meters',
#  '1330 meters',
#  '442 meters',
#  '',
#  '1600 meters',
#  '1813 meters',
#  '4000 meters',
#  '1500 meters',
#  '4300 feet',
#  '',
#  '1450 meters',
#  '',
#  '',
#  '',
#  '900-1200 meters',
#  '1650 meters',
#  '',
#  '',
#  '1227 meters',
#  '1200 meters',
#  '1650 meters',
#  '1700 meters',
#  '1100 meters',
#  '1300 meters',
#  '',
#  '1100-1300 range',
#  '',
#  '4200 feet',
#  '1000 meters',
#  '4300 feet',
#  '',
#  '1880 meters',
#  '1750 meters',
#  '',
#  '',
#  '1600 meters',
#  '1900 meters',
#  '',
#  '2100 meters',
#  '',
#  '',
#  '442 meters',
#  '1261 meters',
#  '1000 meters',
#  '800 meters',
#  '1483 meters',
#  '1500 meters',
#  '1750 meters',
#  '1300 meters',
#  '',
#  '',
#  '1000 meters',
#  '4300 feet',
#  '1200 meters',
#  '175 meters',
#  '16001950 meters',
#  '1600-1800 meters',
#  '1880 meters',
#  '1800 meters',
#  '890 meters',
#  '1901 meters',
#  '168 meters',
#  '',
#  '1550 meters',
#  '1500 meters',
#  '1450 meters',
#  '1200 meters',
#  '1600 meters',
#  '1350 meters',
#  '1500 meters',
#  '1400-1900 range',
#  '1500 meters',
#  '800 meters',
#  '1653 meters',
#  '16001950 meters',
#  '1800 meters',
#  'unkown',
#  '1450 meters',
#  '1350 meters',
#  '5000 feet',
#  '',
#  '1800 meters',
#  '4300 feet',
#  '1500 meters',
#  '532 meters',
#  '1089 meters',
#  '16001950 meters',
#  '700 meters',
#  '1750 meters',
#  '1380 meters',
#  '1000 meters',
#  '950 meters',
#  '4600 feet',
#  '1000 meters',
#  '900 meters',
#  '1200 meters',
#  '1850 meters',
#  '1799 meters',
#  '',
#  '905 meters',
#  '1 meters',
#  '700-800 meters',
#  '',
#  '1200 meters',
#  '1200-1400 range',
#  '',
#  '1300 meters',
#  '',
#  '1400 meters',
#  '',
#  '',
#  '16001950 meters',
#  '1880 meters',
#  '1300-1400 meters',
#  '',
#  '890 meters',
#  '894 meters',
#  '872 meters',
#  '1473 meters',
#  '1645 meters',
#  '442 meters',
#  '1550 meters',
#  '13001800 meters',
#  '4500 feet',
#  '1500 meters',
#  '900-1100 range',
#  '1200 meters',
#  '1800 meters',
#  '2800 feet',
#  '1500 meters',
#  '1100-1300 range',
#  '1250 meters',
#  '1600-1950 meters',
#  '1750 meters',
#  '1000 meters',
#  '1000 meters',
#  '16001950 meters',
#  '750 meters',
#  '1200 meters',
#  '1200 meters',
#  '',
#  '1500-1750 meters',
#  '1750 meters',
#  '4500 feet',
#  '1600-1950 meters',
#  '',
#  '1050-1850 meters',
#  '',
#  '',
#  '1800 meters',
#  '',
#  '',
#  '890 meters',
#  '1350 meters',
#  '1500 meters',
#  '350 meters',
#  '2000 meters',
#  '775 meters',
#  '1200 meters',
#  '1600 meters',
#  '1059 meters',
#  '1300 meters',
#  '11000 meters',
#  '1400-1900 range',
#  '1400 meters',
#  '1500 meters',
#  '1500 meters',
#  '',
#  '1800-2000 range',
#  '1750 meters',
#  '5440-5760 meters',
#  '1450 meters',
#  '1248 meters',
#  '1040 meters',
#  '1400 meters',
#  '',
#  '1050-1850 meters',
#  '',
#  '1754 meters',
#  '1700 meters',
#  '905 meters',
#  '1250 meters',
#  '1900 meters',
#  '1040 meters',
#  '4000 feet',
#  '900 meters',
#  '1200-2000 meters',
#  '1200 meters',
#  '1500 meters',
#  '1800 meters',
#  '16001950 meters',
#  '1400 meters',
#  '1550 meters',
#  '1250 meters',
#  '4300 feet',
#  '1380 meters',
#  '1200 meters',
#  '1100 meters',
#  '1800 meters',
#  '1700 meters',
#  '4000 feet',
#  '4000 feet',
#  '1500 meters',
#  '518 meters',
#  '650 meters',
#  '1250 meters',
#  '1850 meters',
#  '1400 meters',
#  '905 meters',
#  '1100 meters',
#  '1500 meters',
#  '16001950 meters',
#  '1442 meters',
#  '5000 feet',
#  '165 meters',
#  '',
#  '',
#  '1300 meters',
#  '1550 meters',
#  '1200 meters',
#  '1200 meters',
#  '14001850 feet',
#  '16001950 meters',
#  '',
#  '1100 meters',
#  '',
#  '890 meters',
#  '934 meters',
#  '1300 meters',
#  '1200 meters',
#  '1300 meters',
#  '',
#  '1 meters',
#  '',
#  '1700 meters',
#  '1550 meters',
#  '1200 meters',
#  '1296 meters',
#  '1400-1900 range',
#  '1240 meters',
#  '1500 meters',
#  '1800 meters',
#  '',
#  '1500 meters',
#  '-',
#  '1100 meters',
#  '950 meters',
#  '18005900 meters',
#  '',
#  '1400 meters',
#  '1800 meters',
#  '',
#  '4000 feet',
#  '1050 meters',
#  '',
#  '200 meters',
#  '',
#  '1200-1300 meters',
#  '800 meters',
#  '1400-1500 meters',
#  '1317 meters',
#  '1400-1900 range',
#  '1200-1400 range',
#  '',
#  '',
#  '1750 meters',
#  '1750 meters',
#  '1750 meters',
#  '1250 meters',
#  '1150 meters',
#  '16001950 meters',
#  '900-1050 meters',
#  '890 meters',
#  '1250 meters',
#  '1400 meters',
#  '4000 feet',
#  '800 meters',
#  '1400-1500 meters',
#  '1600 meters',
#  '',
#  '1500-1700 meters',
#  '1260 meters',
#  '4300 feet',
#  '1750 meters',
#  '4300 feet',
#  '1679 meters',
#  '1100 meters',
#  '1650 meters',
#  '',
#  '1250 meters',
#  '16001950 meters',
#  '',
#  '1600 meters',
#  '1500 meters',
#  '1700 meters',
#  '1700 meters',
#  '518 meters',
#  '',
#  '1600 meters',
#  '1600 meters',
#  '',
#  '2285 meters',
#  '1 meters',
#  '1400 meters',
#  '1296 meters',
#  '1000 meters',
#  'Huanuco',
#  '1260 meters',
#  '1170 meters',
#  '',
#  '16001950 meters',
#  '1560 meters',
#  '1400 meters',
#  '1300 meters',
#  '1170 meters',
#  '1300 meters',
#  '1350 meters',
#  '1150 meters',
#  '1250 meters',
#  '1450 meters',
#  '442 meters',
#  '',
#  '1750 meters',
#  '1750 meters',
#  '1396 meters',
#  '982 meters',
#  '',
#  '934 meters',
#  '1850 meters',
#  '1550 meters',
#  '1580 meters',
#  '1268 meters',
#  '',
#  '5500 meters',
#  '1450 meters',
#  '1100 meters',
#  '5000 feet',
#  '',
#  '1300 meters',
#  '200 meters',
#  '600 meters',
#  '4300 feet',
#  '1750 meters',
#  '1300 meters',
#  '',
#  '5500-6000 meters',
#  '441 meters',
#  '1170 meters',
#  '4300 feet',
#  '1100 meters',
#  '12001400 feet',
#  '950 meters',
#  '442 meters',
#  '1100 meters',
#  '',
#  '1450 meters',
#  '1 meters',
#  '1500 meters',
#  '1350 meters',
#  '1180 meters',
#  '1100 meters',
#  '650 meters',
#  '1338 meters',
#  '',
#  '533 meters',
#  '4563 feet',
#  '1170 meters',
#  '1250 meters',
#  '',
#  '1100 meters',
#  '900 meters',
#  '1750 meters',
#  '16001950 meters',
#  '',
#  '',
#  '934 meters',
#  '1500 meters',
#  '1000 meters',
#  '1500-1800 range',
#  '1600 meters',
#  '1 meters',
#  '800 meters',
#  '1350 meters',
#  '1500 meters',
#  '',
#  '1700 meters',
#  '1100 meters',
#  '1200-1600 meters',
#  '1200 meters',
#  '800 meters',
#  '1750 meters',
#  '1144 meters',
#  '1350 meters',
#  '1000 meters',
#  '1200 meters',
#  '1800 meters',
#  '1300 meters',
#  '',
#  '894 meters',
#  '1 meters',
#  '1200-1400 meters',
#  '1500 meters',
#  '1500-1700 range',
#  '',
#  '13 meters',
#  '',
#  '1300 meters',
#  '1800 meters',
#  '1250 meters',
#  '1040 meters',
#  '1250 meters',
#  '',
#  '1600 meters',
#  '1600 meters',
#  '1600 meters',
#  '944 meters',
#  '1500-1800 range',
#  '1250 meters',
#  '1300-1400 range',
#  '2500 meters',
#  '600 meters',
#  '800 meters',
#  '1200-1400 range',
#  '1400 meters',
#  '1800-2000 range',
#  '600-700 meters',
#  '894-1183 meters',
#  '940 meters',
#  '1000 meters',
#  '1050 meters',
#  '',
#  '950 meters',
#  '4600 feet',
#  '16001950 meters',
#  '1901 meters',
#  '4000 feet',
#  '1400 meters',
#  '1020 meters',
#  '1250 meters',
#  '13001800 meters',
#  '1877 meters',
#  '',
#  '1000-1500 meters',
#  '',
#  '1000 meters',
#  '1300 meters',
#  '981 meters',
#  '690 meters',
#  '1650 meters',
#  '1000 meters',
#  '1100 meters',
#  '1600 meters',
#  '518 meters',
#  '1900 meters',
#  '973 meters',
#  '1250 meters',
#  '3280 meters',
#  '1 meters',
#  '1 meters',
#  '4001 feet',
#  '1350-1500 range',
#  '1400 meters',
#  '1200-1400 meters',
#  '700 meters',
#  '1300 meters',
#  '1556 meters',
#  '1100 meters',
#  '1350 meters',
#  '1550 meters',
#  '16001950 meters',
#  '',
#  '1250 meters',
#  '4300 feet',
#  '1500 meters',
#  '1250 meters',
#  '900-950 meters',
#  '1600-1800 meters',
#  '',
#  '1700 meters',
#  '1040 meters',
#  '1500-1700 range',
#  '',
#  '774 meters',
#  '1250 meters',
#  '1100 meters',
#  '1550 meters',
#  '1650 meters',
#  '1750 meters',
#  '16001950 meters',
#  '890 meters',
#  '1700 meters',
#  '4000 feet',
#  '1450 meters',
#  '1800 meters',
#  '',
#  '',
#  '1 meters',
#  '1200-1800 meters',
#  '1700 meters',
#  '1260 meters',
#  '',
#  '1400 meters',
#  '1850 meters',
#  '',
#  '150 meters',
#  '750 meters',
#  '1400 meters',
#  '5500-6000 meters',
#  '1650 meters',
#  '1400 meters',
#  '1200 meters',
#  '1400 meters',
#  '940 meters',
#  '',
#  '1200 meters',
#  '190164 feet',
#  '800 meters',
#  '13 meters',
#  '1800 meters',
#  '1100 meters',
#  '850 meters',
#  '1260 meters',
#  '4300 feet',
#  '1400 meters',
#  '1600 meters',
#  '1650 meters',
#  '4921 feet',
#  '',
#  '4500-6000 feet',
#  '4000 feet',
#  '1100 meters',
#  '1400 meters',
#  '',
#  '160-200 meters',
#  '4000 feet',
#  '1200 meters',
#  '1599 meters',
#  '4000 meters',
#  '900 meters',
#  '1200 meters',
#  '400-1250 meters',
#  '600 meters',
#  '1150 meters',
#  '1600 meters',
#  '1100 meters',
#  '1000 meters',
#  '1250 meters',
#  '1100 meters',
#  '1200-1600 meters',
#  '125 meters',
#  '',
#  '1050-1850 range',
#  '',
#  '1100 meters',
#  '4500 feet',
#  '1100 meters',
#  '1400 meters',
#  '110 meters',
#  '1422 meters',
#  '1100 meters',
#  '1550 meters',
#  '1550 meters',
#  '',
#  '4300 feet',
#  '763 meters',
#  '1100 meters',
#  '1750 meters',
#  '1880 meters',
#  '',
#  '',
#  '1500 meters',
#  '1130 meters',
#  '1100 meters',
#  '1350 meters',
#  '1200 meters',
#  '1400 meters',
#  '1200 meters',
#  '1450 meters',
#  '1800 meters',
#  '1000 meters',
#  '1100 meters',
#  '680 meters',
#  '1 meters',
#  '1100 meters',
#  '1400 meters',
#  '1700 meters',
#  '1700 meters',
#  '650 meters',
#  '5000 feet',
#  '1500 meters',
#  '1200 meters',
#  '1002000 feet',
#  '1200 meters',
#  '1200-1400 meters',
#  '1450 meters',
#  '1400-1500 meters',
#  '1200 meters',
#  '1550 meters',
#  '990-1000 meters',
#  '1200-1400 range',
#  '',
#  '1800 meters',
#  '1450 meters',
#  '1000 meters',
#  '',
#  '0 meters',
#  '695 meters',
#  '1100 meters',
#  '5600 feet',
#  '1456 meters',
#  '1500 meters',
#  '2800 feet',
#  '1650 meters',
#  '1300 meters',
#  '1642 meters',
#  '1200 meters',
#  '',
#  '',
#  '1450 meters',
#  ...]

# %%
# test = ['1,000 meters', '999-2000', 'Nothing really']
# canon_col = []

# # Iterate over each element in the list

    
#     for string in list:
        
#         print(string)
#         # Assign empty variables for new values and garbage
#         elt_new = ""
#         elt_garb = ""

#         # Print for user
#         print(f"""Working on {string}""")

#         # Itertate over each character in a string
#         for char in string:

#             # If character is numeric, add to new string in elt
#             if char.isdigit() or "-" in char:
#                 elt_new += char

#             # If not, add to garbage variable
#             else:
#                 elt_garb += char

#         print(f"""
#         Digit result: {elt_new}
#         Non-digit result: {elt_garb}
#         """)

        
            
# str_to_digit(test)


# # res = [int(i) for i in test_string.split() if i.isdigit()] 
# # res

# %%
## harvest year convert to YYYY format for latest year
