# %% [markdown]
# ## Clean up script for arabica_ratings_raw.
# Decisions arround data management will be recorded here.

# %%
# Dependencies
import pandas as pd
import numpy as np
import re

# %%
# Read CSV into pandas dataframe.
df = pd.read_csv('arabica_ratings_raw.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  quality_score  view_certificate_1  view_certificate_2  \
# 0           0          90.58                 NaN                 NaN
# 1           1          89.92                 NaN                 NaN
# 2           2          89.75                 NaN                 NaN
# 3           3          89.00                 NaN                 NaN
# 4           4          88.83                 NaN                 NaN
#
#    Cupping Protocol and Descriptors  View Green Analysis Details  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#    Request a Sample  Species                     Owner Country of Origin  ...  \
# 0               NaN  Arabica                 metad plc          Ethiopia  ...
# 1               NaN  Arabica                 metad plc          Ethiopia  ...
# 2               NaN  Arabica  Grounds for Health Admin         Guatemala  ...
# 3               NaN  Arabica       Yidnekachew Dabessa          Ethiopia  ...
# 4               NaN  Arabica                 metad plc          Ethiopia  ...
#
#   Quakers  Color Category Two Defects NA.3        Expiration  \
# 0     0.0  Green       0 full defects  NaN   April 3rd, 2016
# 1     0.0  Green       1 full defects  NaN   April 3rd, 2016
# 2     0.0    NaN       0 full defects  NaN    May 31st, 2011
# 3     0.0  Green       2 full defects  NaN  March 25th, 2016
# 4     0.0  Green       2 full defects  NaN   April 3rd, 2016
#
#                    Certification Body  \
# 0  METAD Agricultural Development plc
# 1  METAD Agricultural Development plc
# 2        Specialty Coffee Association
# 3  METAD Agricultural Development plc
# 4  METAD Agricultural Development plc
#
#                                Certification Address  \
# 0  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 1  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 2        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 3  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 4  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
#
#                                Certification Contact  Unnamed: 51 Notes
# 0  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 1  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 2                        Chris Buck - (562) 624-4100          NaN   NaN
# 3  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
# 4  Aman Adinew (Emebet Dinku) - +251-116-292534, ...          NaN   NaN
#
# [5 rows x 53 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                            int64
# quality_score                       float64
# view_certificate_1                  float64
# view_certificate_2                  float64
# Cupping Protocol and Descriptors    float64
# View Green Analysis Details         float64
# Request a Sample                    float64
# Species                              object
# Owner                                object
# Country of Origin                    object
# Farm Name                            object
# Lot Number                           object
# Mill                                 object
# ICO Number                           object
# Company                              object
# Altitude                             object
# Region                               object
# Producer                             object
# Number of Bags                        int64
# Bag Weight                           object
# In-Country Partner                   object
# Harvest Year                         object
# Grading Date                         object
# Owner.1                              object
# Variety                              object
# Status                               object
# Processing Method                    object
# NA                                   object
# Aroma                               float64
# Flavor                              float64
# Aftertaste                          float64
# Acidity                             float64
# Body                                float64
# Balance                             float64
# NA.1                                 object
# Uniformity                          float64
# Clean Cup                           float64
# Sweetness                           float64
# Cupper Points                       float64
# Total Cup Points                     object
# NA.2                                float64
# Moisture                             object
# Category One Defects                 object
# Quakers                             float64
# Color                                object
# Category Two Defects                 object
# NA.3                                float64
# Expiration                           object
# Certification Body                   object
# Certification Address                object
# Certification Contact                object
# Unnamed: 51                         float64
# Notes                                object
# dtype: object

# %%
## Drop columns, view_certificate_1, view_certificate_2, Cupping Protocol and Descriptors, View Green Analysis Details, Request a Sample. No data

df1 = df.drop(columns =['view_certificate_1','view_certificate_2','Cupping Protocol and Descriptors','View Green Analysis Details','Request a Sample','NA.1','NA.2','NA.3'])

# %%
## Scan for N/A and convert to blank
## Count number of blanks per column 
df1=df1.replace('n/a',"",regex=True)
df1=df1.replace(np.nan,"",regex=True)

# %%
df1= df1.drop(columns =['Unnamed: 0'])

# %%
df1.index.name = 'ID'

# %%
## quality score convert to int
df1.astype({'quality_score':'int32'}).dtypes
# Out:
# quality_score              int32
# Species                   object
# Owner                     object
# Country of Origin         object
# Farm Name                 object
# Lot Number                object
# Mill                      object
# ICO Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number of Bags             int64
# Bag Weight                object
# In-Country Partner        object
# Harvest Year              object
# Grading Date              object
# Owner.1                   object
# Variety                   object
# Status                    object
# Processing Method         object
# NA                        object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean Cup                float64
# Sweetness                float64
# Cupper Points            float64
# Total Cup Points          object
# Moisture                  object
# Category One Defects      object
# Quakers                   object
# Color                     object
# Category Two Defects      object
# Expiration                object
# Certification Body        object
# Certification Address     object
# Certification Contact     object
# Unnamed: 51               object
# Notes                     object
# dtype: object

# %%
df2 = df1.copy()
df3 = df1.copy()

# %%
## remove lbs/kgs before counter
counter = -1
        
for row in df3['Bag Weight']:
   counter += 1
   if "kg" in row and "lbs" in row:
        df3.iloc[counter, 13] = ""

# %%
## list keeping track of cells with lbs for conversion later
counter = 0
idx_lst = []
for idx, row in enumerate(df3['Bag Weight']):
    if "lbs" in row:
        counter += 1

        idx_lst.append(idx)

# %%
counter = -1
        
for row in df2['Bag Weight']:
   counter += 1
   if "kg" in row and "lbs" in row: 
        df2.iloc[counter, 13] = 0

# %%
## Bag Weight convert to all kg. Drop all letters and make int
# if the cell has lbs and kg make the cell empty

counter = -1
        
for row in df2['Bag Weight']:
   counter += 1
   if row ==0:
       continue
   if "kg" in row:
        fixed = re.sub(r'[a-z]+','',row,re.I) 
        df2.iloc[counter, 13] = fixed
   if "lbs" in row:
        fixed= re.sub(r'[a-z]+','',row,re.I)
        df2.iloc[counter, 13] = fixed

# %%
#type conversion

df2['Bag Weight'] = df2['Bag Weight'].astype(int)

# %%
## convert lbs to kg
for i in idx_lst:
   df2.iloc[i,13]=df2.iloc[i,13]*.453592

# %%
df2.to_csv('testing.csv')

# %%
df2.dtypes
# Out:
# quality_score            float64
# Species                   object
# Owner                     object
# Country of Origin         object
# Farm Name                 object
# Lot Number                object
# Mill                      object
# ICO Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number of Bags             int64
# Bag Weight               float64
# In-Country Partner        object
# Harvest Year              object
# Grading Date              object
# Owner.1                   object
# Variety                   object
# Status                    object
# Processing Method         object
# NA                        object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean Cup                float64
# Sweetness                float64
# Cupper Points            float64
# Total Cup Points          object
# Moisture                  object
# Category One Defects      object
# Quakers                   object
# Color                     object
# Category Two Defects      object
# Expiration                object
# Certification Body        object
# Certification Address     object
# Certification Contact     object
# Unnamed: 51               object
# Notes                     object
# dtype: object

# %% [markdown]
# ## Altitude String Observations
#
# ### Observed
# 1. Since this data collects from bilingual participants, abbreviations differ.
#     - MSNM: Spanish — meters above sea level
#     - MASL: English — meters above sea level
#     - F: English — feet
#     - 公尺: Chinese — meter
# 2. There is the appearance of ranges (i.e. 640m-1400m).
#     - This is difficult because it requires making a decision about the data. Maybe we set the data for ranges in separate columns.
#
# ### Conclusions
# The majority of the data is in meters, so it will be our goal to convert all values to meters, therefore:
# 1. First, cleaned of any debris (non-values).
# 2. Second, the data must be sorted to find values that are not meters and convert them.
# 3. Third, the data must be split by lower and upper ranges.

# %%
##Fix altitude data

# Function for checking string for number
def hasNumbers(inputString):
    return any(char.isdigit() for char in inputString)

# Assign alt column to variable (as series)
alt = df2['Altitude']
count_y = 0
count_y_num = 0
count_y_f = 0
count_garb = 0

str_meter = []
str_feet = []
str_garb = []
str_num = []

for idx, elt in enumerate(alt):
    if 'm' in elt.lower() or '公尺' in elt.lower():
        count_y += 1
        str_meter.append(elt)
        print(f'yes at {elt}')
    else:
        if hasNumbers(elt):
            if 'f' in elt.lower():
                count_y_f += 1
                str_feet.append(elt)
                print(f'#--f num at {elt}')
            if 'f' not in elt.lower():
                count_y_num += 1
                str_num.append(elt)
                print(f'#### num at {elt}')
        else:
            count_garb += 1
            str_garb.append(elt)
            print(f'(GARB) at {elt}')
            
print(f"""
M is present {count_y} times.
F is present {count_y_f} times.
Otherwise, number is present {count_y_num} times.
Garbage present {count_garb} times.
---
Total count: {count_y+count_y_f+count_y_num+count_garb}
""")
# Out:
# #### num at 1950-2200
# #### num at 1950-2200
# yes at 1600 - 1800 m
# #### num at 1800-2200
# #### num at 1950-2200
# (GARB) at
# (GARB) at
# #### num at 1570-1700
# #### num at 1570-1700
# #### num at 1795-1850
# #### num at 1855-1955
# yes at Meters above sea level: 1.872
# yes at Meters above sea level: 1.943
# #--f num at 2000 ft
# #### num at 1570-1700
# yes at Meters above sea level: 2.080
# yes at 1200-1800m
# (GARB) at
# #### num at 1450
# yes at 1700-2000m
# yes at Meters above sea level: 2.019
# yes at 1300 MSNM
# #### num at 1320
# yes at Meters above sea level: 2.112
# (GARB) at
# yes at 1250m
# (GARB) at
# #### num at 1950
# #### num at 1400
# #### num at 1200
# (GARB) at
# (GARB) at
# #### num at 1300
# #### num at 1300
# #### num at 1750-1800
# #### num at 1800
# (GARB) at
# (GARB) at
# (GARB) at
# yes at Meters above sea level: 1.941
# #### num at 1300
# #### num at 1.2
# #### num at 1.2
# yes at 1000 M
# #### num at 1754
# yes at 1250m
# (GARB) at
# yes at 900-1,500m
# yes at 1520m-2200m
# yes at 1400-1900M
# yes at 1500-2000 m
# #--f num at 1400ft
# (GARB) at
# #### num at 1400-1900
# yes at 1800 msnm
# #### num at 1600
# #### num at 1800-2000
# #### num at 5000
# #### num at 4650
# (GARB) at
# (GARB) at
# yes at 1,700 mts
# yes at 1500 meters
# yes at 1300~1400 m.s.l
# (GARB) at
# #### num at 1680
# yes at 1900M
# #### num at 1800-2000
# #### num at 1600
# yes at 5600-5760 METROS
# #### num at 1800-2000
# #### num at 1950
# (GARB) at
# yes at 1250m
# yes at 1400 M
# #### num at 1700
# #### num at 1770
# #### num at 1300
# yes at 1300 msnm
# yes at above 1600 M
# yes at Above 1200 M
# (GARB) at
# (GARB) at
# (GARB) at
# yes at 1550 msnm
# #### num at 1550
# yes at 1250-1400 meter
# yes at 1400 msm
# (GARB) at
# yes at 2.560 msnm
# #### num at 1700
# (GARB) at
# yes at 2136 msnm
# (GARB) at
# (GARB) at
# (GARB) at
# #### num at 1800
# (GARB) at
# #### num at 1900
# #### num at 1300
# #### num at -1
# #### num at 1580
# yes at 1100m
# yes at 1400 MASL
# (GARB) at
# #--f num at 3500-5200 feet
# (GARB) at
# yes at De 1600 a 1950 msnm
# yes at 800 M
# yes at 1620M
# yes at De 1600 a 1950 msnm
# #### num at 1200
# yes at 1200m
# yes at 1000 m
# (GARB) at
# #### num at 350
# #### num at 1400-1900
# (GARB) at
# yes at 1500-2000 m
# yes at 1500-2000 m
# (GARB) at
# #### num at 1800
# yes at 1450 msnm
# yes at 1200 mts
# yes at 800-1050m
# #### num at 1350
# #### num at 1200
# #### num at 170
# #### num at 1150
# #### num at 1600
# #### num at 1750
# yes at 1900M
# yes at 1750M
# #### num at 1200
# (GARB) at
# yes at 1000 M
# #### num at 1550
# #### num at 2000
# #### num at 4300
# #### num at 5000
# #### num at 1200
# yes at 1700-1850m
# (GARB) at
# yes at 1500-2000 m
# #### num at 1754
# #### num at 1500
# (GARB) at
# #### num at 1800
# #--f num at 5000 FT.
# #### num at 4000 PSN
# #### num at 1550
# yes at 1600 a 1900 msnm
# (GARB) at
# yes at 1750 msnm
# yes at 1450 ~ 1700 m
# yes at 1800 msnm
# yes at 1300m
# yes at 1100m
# #### num at 1200
# #### num at 1750
# #### num at 1680
# #### num at 1700
# #### num at 1800
# yes at Above 1100m
# #### num at 4300
# yes at 2000 m
# #### num at 1350
# #### num at 1500
# (GARB) at
# yes at mmm
# (GARB) at TEST
# #### num at 1300
# #### num at 1400
# (GARB) at
# yes at De 1600 a 1950 msnm
# yes at 1200M
# (GARB) at
# #### num at 900
# (GARB) at
# #### num at 1800
# #### num at 1500
# (GARB) at
# #### num at 1500
# (GARB) at
# yes at 442 msnm
# #### num at 1800
# #### num at 1700
# yes at 1200m to 1350m
# yes at 900-1200m
# #--f num at 3600-6200 ft
# #--f num at 4400-4700 ft
# #### num at 1000
# #### num at 1200
# #### num at 2560
# #### num at 1500
# #### num at 3607
# #### num at 1400
# yes at De 1600 a 1950 msnm
# yes at De 1600 a 1950 msnm
# #### num at 1800
# yes at 442 msnm
# yes at 1620M
# #### num at 1600
# yes at 4000 PSNM
# #### num at 1700
# (GARB) at
# #### num at 1450
# #### num at 1170
# #### num at 1400
# yes at 1700m
# #### num at 1700
# (GARB) at
# #### num at 1700
# #### num at 3664
# #### num at 1565
# #### num at 3280
# yes at De 1600 a 1950 msnm
# yes at de 900 a 1100 msnm
# #### num at 1150
# #### num at 1850
# yes at 1545-1668 MASL
# #### num at 1400
# #### num at 1530
# (GARB) at
# yes at approx. 1'500 metres a.s.l.
# yes at 894m - 1183m
# #### num at 4300
# yes at 1500 meters
# yes at 1750 msnm
# (GARB) at
# yes at 1500-1700m
# (GARB) at
# #### num at 442
# #### num at 968
# (GARB) at
# yes at De 1600 a 1950 msnm
# #### num at 1550
# (GARB) at
# #### num at 1480
# yes at 1800m
# (GARB) at
# #### num at 1800
# #### num at 1500
# yes at 5440 - 5760 METROS
# #### num at 1600
# yes at 4000 PSNM
# yes at 4000 PSNM
# #### num at 1480
# #### num at 1450
# yes at De 1600 a 1950 msnm
# yes at 1550 m
# #### num at 1260
# yes at 1700 msnm
# yes at Above 1200 M
# (GARB) at -
# #### num at 1650
# yes at 1700m
# (GARB) at
# #### num at 890
# #### num at 1300
# #### num at 1350
# #### num at 934
# #### num at 1200
# #### num at 442
# (GARB) at
# (GARB) at none
# (GARB) at
# (GARB) at
# yes at De 1600 a 1950 msnm
# yes at 950公尺
# #### num at 1550
# #### num at 900
# #### num at 1500
# #### num at 1400
# #### num at 2527
# (GARB) at
# #### num at 1850
# #### num at 1500
# #### num at 1200
# #### num at 1
# yes at 480-570M
# #### num at 1650-1703
# #### num at 1200
# #### num at 1200-1400
# yes at 4000 PSNM
# #### num at 1260
# yes at 800 meters above sea level
# yes at 1750 msnm
# #### num at 4300
# #### num at 1218
# #### num at 1300
# yes at 1.250 m
# #--f num at 4921ft
# (GARB) at
# (GARB) at
# #### num at 1800
# #### num at 890
# #### num at 442
# #### num at 750
# (GARB) at
# #### num at 1650
# yes at 442 msnm
# #### num at 1400
# #--f num at 2800 ft
# yes at De 1600 a 1950 msnm
# #### num at 1500-1600
# yes at 1750 msnm
# #### num at 1750
# (GARB) at
# #### num at 700
# yes at 1300 mts
# yes at 1600 m.s.n.m
# yes at 1600 msnm
# (GARB) at
# #### num at 890
# #### num at 1700
# #### num at 1400
# #### num at 1250
# #### num at 934
# #### num at 1200
# #### num at 1350
# #### num at 800++
# yes at 1550-1700m
# yes at 4451 METROS
# yes at 1750 MSNM
# #### num at 1800 - 2000
# #### num at 4300
# #### num at 4300
# yes at 1750 msnm
# #### num at 1450
# #### num at 4300
# #### num at 1100
# yes at 1200-1600masl
# #### num at 5000
# (GARB) at
# #### num at 890
# #### num at 3702
# (GARB) at
# #### num at 1100
# yes at De 1600 a 1950 msnm
# #### num at 1200
# yes at 1700-2000m
# #### num at 1800
# #### num at 1600
# #### num at 1550
# #### num at 1550
# yes at 1000 M
# yes at DE 1.600 A 1.950 MSNM
# #### num at 1000
# yes at 2136 msnm
# yes at 1100m
# #### num at 1799
# (GARB) at
# #### num at 1850
# #### num at 1000
# #### num at 4000
# yes at De 1600 a 1950 msnm
# yes at 1400M
# #### num at 1500
# #### num at 1600 on Average
# (GARB) at
# yes at 1850 MSNM
# yes at 1400 mts
# #### num at 1650
# #### num at 1350
# yes at 1750 msnm
# yes at 1750 msnm
# #### num at 1170
# #### num at 940
# #### num at 1400
# #### num at 5000
# yes at De 1600 a 1950 msnm
# #--f num at 4,600 ft.
# (GARB) at
# #### num at 1600
# #### num at 439
# #### num at 1700
# #### num at 442
# #### num at 1850
# (GARB) at
# #### num at 1800
# #### num at 1200
# #### num at 1330
# yes at 442 msnm
# (GARB) at
# #### num at 1600
# #### num at 1813
# yes at 4000 PSNM
# yes at 1500 msnm
# #### num at 4300
# (GARB) at
# yes at 1450 msnm
# (GARB) at
# (GARB) at
# (GARB) at
# yes at 900-1200mtr
# #### num at 1650
# (GARB) at
# (GARB) at
# #### num at 1227
# #### num at 1200
# yes at 1650 msnm
# #### num at 1700
# #### num at 1100
# yes at 1300 MSNM
# (GARB) at
# #### num at 1100-1300
# (GARB) at
# #--f num at 4200 FEET
# yes at 1000 MSNM
# #### num at 4300
# (GARB) at
# #### num at 1880
# yes at 1750 msnm
# (GARB) at
# (GARB) at
# #### num at 1600
# #### num at 1900
# (GARB) at
# #### num at 2100
# (GARB) at
# (GARB) at
# yes at 442 msnm
# #### num at 1261
# yes at 1000 M
# yes at 800公尺
# #### num at 1483
# yes at 1500 MSNM
# yes at 1750 msnm
# #### num at 1300
# (GARB) at
# (GARB) at
# #### num at 1000
# #### num at 4300
# yes at 1200m
# #### num at 175
# yes at De 1600 a 1950 msnm
# yes at 1600-1800msnm
# yes at 1880 msnm
# yes at 1800 m.s.n.m
# #### num at 890
# #### num at 1901
# #### num at 16.8
# (GARB) at
# #### num at 1550
# #### num at 1500
# #### num at 1450
# #### num at 1200
# #### num at 1600
# #### num at 1350
# yes at 1500msnm
# #### num at 1400-1900 PSN
# yes at approx.1'500 metres a.s.l.
# #### num at 800++
# #### num at 1653
# yes at De 1600 a 1950 msnm
# #### num at 1800
# (GARB) at unkown
# yes at 1450 MSNN
# #### num at 1350
# #### num at 5000 Pies
# (GARB) at
# #### num at 1800
# #### num at 4300
# #### num at 1500
# #### num at 532
# #### num at 1089
# yes at DE 1.600 A 1.950 MSNM
# #### num at 700
# yes at 1750 msnm
# #### num at 1380
# yes at 1000m
# yes at 950m
# #--f num at 4,600 ft.
# yes at 1000m
# yes at 900m
# yes at 1200 mts
# yes at 1850 m
# #### num at 1799
# (GARB) at
# #### num at 905
# #### num at 1
# yes at 700-800M
# (GARB) at
# #### num at 1200
# #### num at 1200-1400
# (GARB) at
# yes at 1300 M
# (GARB) at
# #### num at 1400
# (GARB) at
# (GARB) at
# yes at De 1.600 a 1.950 msn
# yes at 1880 msnm
# yes at 1300-1400m
# (GARB) at
# #### num at 890
# #### num at 894
# #### num at 872
# #### num at 1473
# #### num at 1645
# #### num at 442
# #### num at 1550
# yes at 1300 A 1800 METROS SOBRE EL NIVEL DEL MAR
# #### num at 4500 Pies
# yes at 1500MSNM
# #### num at 900-1100
# #### num at 1200
# #### num at 1800
# #--f num at 2800 ft
# yes at 1500 MSNM
# #### num at 1100-1300
# #### num at 1250
# yes at 1600 - 1950 msnm
# yes at 1750 msnm
# yes at 1000 msnm
# yes at 1000 MSNM
# yes at DE 1600 a 1950 msnm
# #### num at 750
# #### num at 1200
# #### num at 1200
# (GARB) at
# yes at 1500-1750 msnm
# yes at 1750 msnm
# #### num at 4500
# yes at 1600 - 1950 MSNM
# (GARB) at
# yes at 1050 - 1850 msnm
# (GARB) at
# (GARB) at
# yes at 1800 msnm
# (GARB) at
# (GARB) at
# #### num at 890
# #### num at 1350
# #### num at 1500
# #### num at 350
# #### num at 2000
# #### num at 775
# yes at 1,200 masl
# yes at 1,600 + meters above sea level
# #### num at 1059
# yes at 1,300 meters
# yes at 11000 metros
# #### num at 1400-1900
# #### num at 1400
# yes at 1500 MSNM
# yes at 1500 MSNM
# (GARB) at
# #### num at 1800 - 2000
# yes at 1750 msnm
# yes at 5440-5760 METROS
# #### num at 1450
# #### num at 1248
# yes at 1040M
# yes at 1400 m
# (GARB) at
# yes at 1050 - 1850 msnm
# (GARB) at
# #### num at 1754
# #### num at 1700
# #### num at 905
# #### num at 1250
# #### num at 1900
# #### num at 1040
# #### num at 4000PSN
# #### num at 900
# yes at 1200-2000m
# yes at 1200 m
# yes at 1500 MSNM
# yes at 1800 mts
# yes at De 1600 a 1950 msnm
# yes at 1,400 METER ABOVE SEA LEVEL
# #### num at 1550
# #### num at 1250
# #### num at 4300
# #### num at 1380
# yes at 1200 mts
# #### num at 1100
# #### num at 1800
# #### num at 1700
# #### num at 4000
# #### num at 4000
# #### num at 1500
# #### num at 518
# #### num at 650
# #### num at 1250
# #### num at 1850
# #### num at 1400
# #### num at 905
# #### num at 1100
# #### num at 1500
# yes at De 1600 a 1950 msnm
# yes at 1442 M
# #--f num at 5000 FT.
# #### num at 1.65
# (GARB) at
# (GARB) at
# #### num at 1300
# #### num at 1550
# #### num at 1200
# #### num at 1200
# #### num at 1400 thru 1850
# yes at DE 1.600 A 1.950 MSNM
# (GARB) at
# #### num at 1100
# (GARB) at
# #### num at 890
# #### num at 934
# #### num at 1300
# #### num at 1200
# #### num at 1300
# (GARB) at
# #### num at 1
# (GARB) at
# #### num at 1700
# #### num at 1550
# yes at 1200公尺
# #### num at 1296
# #### num at 1400- 1900
# yes at 1240 M
# #### num at 1500
# yes at 1800 msnm
# (GARB) at
# #### num at 1500
# (GARB) at -
# #### num at 1100
# #### num at 950
# yes at 1,800 meters (5,900
# (GARB) at
# yes at 1400 MASL
# yes at 1800 msnm
# (GARB) at
# #### num at 4000
# #### num at 1050
# (GARB) at
# yes at 200 M
# (GARB) at
# yes at 1200-1300m dpl
# #### num at 800++
# yes at 1,400-1,500 m
# #### num at 1317
# #### num at 1400-1900
# #### num at 1200-1400
# (GARB) at
# (GARB) at
# yes at 1750 msnm
# yes at 1750 msnm
# yes at 1750 msnm
# #### num at 1250
# #### num at 1150
# yes at De 1.600 a 1.950 msnm
# yes at 900-1050m
# #### num at 890
# #### num at 1250
# #### num at 1400
# #### num at 4000
# #### num at 800++
# yes at 1,400-1,500 m
# #### num at 1600
# (GARB) at
# yes at 1,500-1,700m
# #### num at 1260
# #### num at 4300
# yes at 1750 msnm
# #### num at 4300
# #### num at 1679
# #### num at 1100
# #### num at 1650
# (GARB) at
# yes at 1.250 m
# yes at DE 1.600 A 1.950 MSNM
# (GARB) at
# #### num at 1600
# #### num at 1500
# #### num at 1700
# #### num at 1700
# #### num at 518
# (GARB) at
# #### num at 1600
# #### num at 1600
# (GARB) at
# #### num at 2285
# #### num at 1
# yes at 1400 mts
# #### num at 1296
# yes at 1000m
# (GARB) at Huanuco
# #### num at 1260
# #### num at 1170
# (GARB) at
# yes at De 1600 a 1950 msnm
# #### num at 1560
# #### num at 1400
# #### num at 1300
# #### num at 1170
# #### num at 1300
# #### num at 1350
# #### num at 1150
# #### num at 1250
# #### num at 1450
# yes at 442 MSNM
# (GARB) at
# #### num at 1750
# yes at 1750 m.s.n.m
# #### num at 1396
# #### num at 982
# (GARB) at
# #### num at 934
# #### num at 1850
# #### num at 1550
# #### num at 1580
# #### num at 1268
# (GARB) at
# yes at 5500 METROS
# yes at 1450 M
# #### num at 1100
# #--f num at 5000 FT.
# (GARB) at
# #### num at 1300
# yes at 200 M
# yes at 600 M
# #### num at 4300
# yes at 1750 msnm
# #### num at 1300
# (GARB) at
# yes at 5,500-6,000 PSNM
# #### num at 441
# #### num at 1170
# #### num at 4300
# yes at 1100m
# #### num at 1200 A 1400
# yes at 950m
# yes at 442 MSNM
# #### num at 1100
# (GARB) at
# #### num at 1450
# #### num at 1
# #### num at 1500
# #### num at 1350
# yes at 1180M
# #### num at 1100
# yes at 650 M
# #### num at 1338
# (GARB) at
# #### num at 533
# #### num at 4563
# #### num at 1170
# #### num at 1250
# (GARB) at
# #### num at 1100
# #### num at 900
# #### num at 1750
# yes at De 1600 a 1950 msnm
# (GARB) at
# (GARB) at
# #### num at 934
# #### num at 1500
# #### num at 1000
# #### num at 1500-1800
# #### num at 1600
# #### num at 1
# #### num at 800++
# #### num at 1350
# #### num at 1500
# (GARB) at
# #### num at 1700
# #### num at 1100
# yes at 1,200-1,600m
# yes at 1200 M
# yes at 800 M
# yes at 1750 msnm
# #### num at 1144
# #### num at 1350
# #### num at 1000
# #### num at 1200
# yes at 1800 msnm
# #### num at 1300
# (GARB) at
# #### num at 894
# #### num at 1
# yes at 1200-1400 MASL
# #### num at 1500
# #### num at 1500 - 1700
# (GARB) at
# #### num at 1.3
# (GARB) at
# #### num at 1300
# #### num at 1800
# #### num at 1250
# yes at 1040M
# #### num at 1250
# (GARB) at
# yes at 1600 msnm
# #### num at 1600
# #### num at 1600
# #### num at 944
# #### num at 1500-1800
# yes at 1250m
# #### num at 1300- 1400
# yes at 2500M
# yes at 600M
# #### num at 800++
# #### num at 1200-1400
# yes at 1400 m.s.n.m.
# #### num at 1800 - 2000
# yes at 600-700 M
# yes at 894m - 1183m
# #### num at 940
# yes at 1000m
# yes at 1050m
# (GARB) at
# yes at 950m
# #--f num at 4,600 ft.
# yes at De 1.600 a 1.950 msn
# #### num at 1901
# #### num at 4000
# #### num at 1400
# #### num at 1020
# #### num at 1250
# yes at 1300 A 1800 MTRS. A NIVEL DEL MAR
# #### num at 1877
# (GARB) at
# yes at 1,000-1,500m
# (GARB) at
# yes at 1000 M
# #### num at 1300
# #### num at 981
# #### num at 690
# #### num at 1650
# #### num at 1000
# yes at 1100m
# yes at 1600 m.s.n.m
# #### num at 518
# #### num at 1900
# #### num at 973
# #### num at 1250
# #### num at 3280
# #### num at 1
# #### num at 1
# #### num at 4001
# #### num at 1350-1500
# yes at 1400 MSNM
# yes at 1200-1400 MASL
# yes at 700M
# yes at 1300m
# yes at 1556M
# #### num at 1100
# #### num at 1350
# yes at 1,550 meters
# yes at DE 1.600 A 1950 msnm
# (GARB) at
# #### num at 1250
# #### num at 4300
# #### num at 1500
# #### num at 1250
# yes at 900-950m
# yes at 1600-1800 msnm
# (GARB) at
# #### num at 1700
# #### num at 1040
# #### num at 1500 - 1700
# (GARB) at
# #### num at 774
# #### num at 1250
# #### num at 1100
# #### num at 1550
# #### num at 1650
# yes at 1750 msnm
# yes at De 1600 a 1950 msnm
# #### num at 890
# #### num at 1700
# #### num at 4000
# #### num at 1450
# #### num at 1800
# (GARB) at
# (GARB) at
# #### num at 1
# yes at 1200-1800M
# #### num at 1700
# #### num at 1260
# (GARB) at
# #### num at 1400
# #### num at 1850
# (GARB) at
# yes at 150 M
# yes at 750 M
# #### num at 1400
# yes at 5,500-6,000 PSNM
# #### num at 1650
# #### num at 1400
# #### num at 1200
# #### num at 1400
# #### num at 940
# (GARB) at
# #### num at 1200
# #### num at 190164
# #### num at 800
# #### num at 1.3
# #### num at 1800
# yes at 1100M
# yes at 850 M
# #### num at 1260
# #### num at 4300
# #### num at 1400
# #### num at 1600
# #### num at 1650
# #--f num at 4921ft
# (GARB) at
# #--f num at 4500-6000 Feet
# #### num at 4000
# #### num at 1100
# #### num at 1400
# (GARB) at
# yes at 160-200M
# #--f num at 4000 ft
# yes at 1200 msm
# yes at 1599M
# yes at 4000 PSNM
# yes at 900 M
# #### num at 1200
# yes at 400-1250m
# yes at 600 M
# #### num at 1150
# #### num at 1600
# #### num at 1100
# #### num at 1000
# #### num at 1250
# #### num at 1100
# yes at 1200-1600masl
# #### num at 1.25
# (GARB) at
# #### num at 1050 - 1850
# (GARB) at
# #### num at 1100
# #### num at 4500
# #### num at 1100
# yes at 1400 MSNM
# yes at 110公尺
# #### num at 1422
# #### num at 1100
# yes at 1550 MTS.
# yes at 1,550 meter
# (GARB) at
# #### num at 4300
# #### num at 763
# #### num at 1100
# yes at 1750 m.s.n.m
# yes at 1880 msnm
# (GARB) at
# (GARB) at
# #### num at 1500
# #### num at 1130
# #### num at 1100
# #### num at 1350
# #### num at 1200
# yes at 1400 MASL
# yes at 1200M
# yes at 1450 MSNM
# #### num at 1800
# #### num at 1000
# #### num at 1100
# #### num at 680
# #### num at 1
# #### num at 1100
# yes at 1400 MSN
# yes at 1700m
# #### num at 1700
# yes at 650 M
# #--f num at 5,000 F
# #### num at 1500
# #### num at 1200
# #### num at 100/2000
# #### num at 1200
# yes at 1200-1400 MASL
# yes at 1450 mals
# yes at 1,400-1,500 m
# yes at 1200 MASL
# #### num at 1550
# yes at 990-1000M
# #### num at 1200-1400
# (GARB) at
# #### num at 1800
# #### num at 1450
# yes at 1000m
# (GARB) at
# #### num at 0
# #### num at 695
# yes at 1,100 m.o.s.l.
# #--f num at 5600 feet
# #### num at 1456
# yes at 1500 mts
# #--f num at 2800 ft
# #### num at 1650
# #### num at 1300
# #### num at 1642
# #### num at 1200
# (GARB) at
# (GARB) at
# #### num at 1450
# (GARB) at
# #### num at 3280
# #### num at 1600
# #### num at 4000PSN
# yes at 758M
# #### num at 1350 ,SNN
# (GARB) at
# yes at 1525 M
# #### num at 1700
# yes at 1100 M
# #### num at 800++
# #### num at 950
# #### num at 1100
# #### num at 200
# #### num at 1901
# #### num at 1600
# #### num at 1100
# #--f num at 3500 ft
# (GARB) at
# #### num at 1700
# #### num at 1200
# yes at 550公尺
# #### num at 1100
# yes at Between 700 and 1,400 meters
# #--f num at 5000 FT.
# yes at 900 M
# yes at 688 M
# yes at 300 M
# #### num at 1186
# (GARB) at
# #### num at 1300
# #### num at 1200
# #### num at 1210
# #### num at 1100
# #### num at 100
# (GARB) at
# yes at 1800 m.s.n.m
# (GARB) at
# #### num at 3825
# yes at 5440-5760 METROS
# yes at 1,100.00 mosl
# yes at 1450 masl
# yes at 1680M
# #### num at 1350
# yes at 1450 mals
# yes at 1300 MSNM
# #### num at 1200
# yes at ~1000 meters
# (GARB) at
# (GARB) at
# #### num at 1200-1500
# yes at 1500msnm
# #### num at 1.85
# yes at 990-1000M
# #### num at 1200
# #### num at 1550
# #### num at 1550
# (GARB) at
# (GARB) at
# (GARB) at
# (GARB) at
# (GARB) at
# #### num at 1400
# #### num at 1200
# yes at 1400 m.s.n.m.
# yes at 4540 METROS
# (GARB) at
# (GARB) at
# #### num at 50
# #### num at 1500
# #### num at 1650
# #### num at 280
# yes at 1250 m
# #### num at 3800
# yes at 4000 P.S.N.M.
# #### num at 1250
# (GARB) at
# yes at 6100 METROS
# #### num at 1450
# #### num at 1450
# yes at 600公尺
# yes at 1,450m
# #### num at 1700
# yes at 600 M
# #### num at 1050
# #### num at 1550
# #### num at 1700
# #### num at 1700
# (GARB) at
# yes at 600 M
# #### num at 4300
# #### num at 940
# (GARB) at
# (GARB) at
# #### num at 995
# #### num at 1400
# #### num at 1600
# #--f num at 3000 ft
# #### num at 4287
# yes at 900 m.s.n.m.
# (GARB) at
# (GARB) at
# yes at 700 M
# #### num at 1400
# #### num at 808
# #### num at 1550
# yes at 1100 - 1275 mts
# yes at 1400 msnm
# #### num at 4300
# #### num at 1250
# #### num at 1550
# #### num at 1000
# #### num at 4300
# (GARB) at
# #### num at 1100
# yes at 850公尺
# (GARB) at
# yes at 200 M
# yes at 150 M
# yes at 250 M
# #### num at 1300
# #### num at 1300
# #### num at 1250
# #### num at 3845
# yes at 1,300 to 1,500 meters
# yes at 250 M
# #### num at 800++
# #### num at 1250
# #### num at 1100
# (GARB) at
# (GARB) at
# (GARB) at
# #### num at 1300
# #### num at 1100
# #### num at 1100
# #### num at 1100
# #### num at 1250
# #### num at 1250
# (GARB) at
# #### num at 1500
# #### num at 1700
# #### num at 1250
# #### num at 1300
# (GARB) at
# #### num at 1901.64
# #### num at 800-1200
# yes at 500-700M
# #### num at 800++
# (GARB) at
# #### num at 1100
# #### num at 1400
# #### num at 1022
# #### num at 1300
# #### num at 1450
# #### num at 1050
# (GARB) at -(average)
# #### num at 1100
# #### num at 4000
# #### num at 1250
# #### num at 800++
# #### num at 4300
# #### num at 1400
# #### num at 975
# #### num at 1264
# (GARB) at
# #### num at 1250
# #### num at 1550
# yes at 1800 msnm
# #--f num at 3,500 - 5,200 feet
# #### num at 1050
# yes at 700M公尺
# yes at 1550 msnm
# #### num at 1550
# #### num at 1100
# yes at 4000 P.S.N.M.
# yes at 4000 P.S.N.M.
# #### num at 800
# #### num at 200
# #### num at 1200
# #### num at 950
# #### num at 750
# (GARB) at
# #### num at 850
# #### num at 1000
# #### num at 4000
# #### num at 1650
# #### num at 1320
# yes at 1300 A 1800 METROS SOBRE EL NIVEL DEL MAR
# (GARB) at
# #### num at 1550
# #### num at 1450
# yes at 1200 m
# #### num at 1700
# #--f num at 2800 ft
# #### num at 1500
# #### num at 1100
# #### num at 1200
# (GARB) at
# #### num at 4000
# #### num at 1350
# #### num at 1400
# #### num at 1300
# #### num at 1550
# #### num at 12OO
# #### num at 1300
# #### num at 1400
# #### num at 1100
# (GARB) at
# #### num at 4300
# #### num at 1320
# #### num at 1250
# #### num at 1350
# #### num at 1850
# #### num at 1150
# (GARB) at
# (GARB) at
# yes at 4000 PSNM
# yes at 800M
# #### num at 1400
# #### num at 1300
# (GARB) at
# yes at 1,600 meters
# #### num at 1400
# #### num at 1200
# (GARB) at
# #### num at 1500
# (GARB) at
# yes at 4000 P.S.N.M
# #### num at 4300
# #### num at 1300
# (GARB) at
# (GARB) at
# (GARB) at
# #### num at 1300
# #### num at 1050
# #### num at 650
# #### num at 1350
# (GARB) at
# yes at 4000 P.S.N.M
# yes at 1200 meters
# #### num at 4300
# #### num at 850
# (GARB) at
# yes at 1200 msm
# #### num at 1248
# (GARB) at
# #### num at 1000
# (GARB) at
# #### num at 4300
# yes at 750-800 M
# (GARB) at
# #### num at 1300
# #### num at 4300
# #### num at 890
# yes at 4000 P.S.N.M.
# #### num at 1500
# yes at 400-1250m
# (GARB) at
# #### num at 1200
# yes at 900-1500 masl
# (GARB) at
# yes at 1200 m
# (GARB) at
# #### num at 1100
# #### num at 4300
# (GARB) at
# (GARB) at
# (GARB) at
# #### num at 1400
# #### num at 3500
# #### num at 1250
# #### num at 1350
# yes at 1000+ meters
# (GARB) at
# #### num at 4300
# (GARB) at
# #### num at 1100
# #### num at 1200
# #### num at 1100
# #### num at 1280
# #### num at 850
# #### num at 1500
# #### num at 1250
# (GARB) at
# (GARB) at
# #### num at 1700
# (GARB) at
# #### num at 4300
# #### num at 1140
# #### num at 1200
# #### num at 1250
# (GARB) at
# (GARB) at
# #### num at 1350
# yes at 1,200 meters
# (GARB) at
# (GARB) at
# yes at 640m-1400m
# yes at 1200 msm
# #### num at 800
# #### num at 1800
# yes at 1,000 meters
# (GARB) at
# yes at 1450 msnm
# yes at 1450 msnm
# yes at 1450 msnm
# #### num at 900
# yes at ~350m
# #### num at 1100
# #### num at 4650
# (GARB) at TEST
# #### num at 1400
#
# M is present 360 times.
# F is present 26 times.
# Otherwise, number is present 700 times.
# Garbage present 226 times.
# ---
# Total count: 1312

# %%
## harvest year convert to YYYY format for latest year
