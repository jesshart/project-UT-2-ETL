# %%
import pandas as pd

# %%
# read region id data into pandas
df_countries = pd.read_csv('../../../DataHub/country_codes/data.csv')
df_countries.head()
# Out:
#   Continent_Name Continent_Code                                  Country_Name  \
# 0           Asia             AS              Afghanistan, Islamic Republic of
# 1         Europe             EU                          Albania, Republic of
# 2     Antarctica             AN  Antarctica (the territory South of 60 deg S)
# 3         Africa             AF      Algeria, People's Democratic Republic of
# 4        Oceania             OC                                American Samoa
#
#   Two_Letter_Country_Code Three_Letter_Country_Code  Country_Number
# 0                      AF                       AFG             4.0
# 1                      AL                       ALB             8.0
# 2                      AQ                       ATA            10.0
# 3                      DZ                       DZA            12.0
# 4                      AS                       ASM            16.0

# %%
# read grower col names into pandas
df = pd.read_csv('retail_col_names.csv')
df = df.iloc[1:]
df.head()
# Out:
#    Country
# 1  Austria
# 2   Cyprus
# 3  Denmark
# 4  Finland
# 5   France

# %%
lst_id = list(df_countries['Country_Name'])
lst_original = list(df['Country'])

# %%
for country in lst_original:
    for id in lst_id:
        if country.lower() in id.lower():  # lower() just in case
            
            print(f"""
            -----
            Changing
            
            Original: {country}
            New: {id}
            """)
            
            country = id
# Out:
#             -----
#             Changing
#
#             Original: Austria
#             New: Austria, Republic of
#
#
#             -----
#             Changing
#
#             Original: Cyprus
#             New: Cyprus, Republic of
#
#
#             -----
#             Changing
#
#             Original: Cyprus, Republic of
#             New: Cyprus, Republic of
#
#
#             -----
#             Changing
#
#             Original: Denmark
#             New: Denmark, Kingdom of
#
#
#             -----
#             Changing
#
#             Original: Finland
#             New: Finland, Republic of
#
#
#             -----
#             Changing
#
#             Original: France
#             New: France, French Republic
#
#
#             -----
#             Changing
#
#             Original: Germany
#             New: Germany, Federal Republic of
#
#
#             -----
#             Changing
#
#             Original: Italy
#             New: Italy, Italian Republic
#
#
#             -----
#             Changing
#
#             Original: Netherlands
#             New: Netherlands, Kingdom of the
#
#
#             -----
#             Changing
#
#             Original: Portugal
#             New: Portugal, Portuguese Republic
#
#
#             -----
#             Changing
#
#             Original: Spain
#             New: Spain, Kingdom of
#
#
#             -----
#             Changing
#
#             Original: Sweden
#             New: Sweden, Kingdom of
#
#
#             -----
#             Changing
#
#             Original: Japan
#             New: Japan
#
#
#             -----
#             Changing
#
#             Original: Norway
#             New: Norway, Kingdom of
#
#
#             -----
#             Changing
#
#             Original: Belgium
#             New: Belgium, Kingdom of
#
#
#             -----
#             Changing
#
#             Original: Bulgaria
#             New: Bulgaria, Republic of
#
#
#             -----
#             Changing
#
#             Original: Czech Republic
#             New: Czech Republic
#
#
#             -----
#             Changing
#
#             Original: Hungary
#             New: Hungary, Republic of
#
#
#             -----
#             Changing
#
#             Original: Latvia
#             New: Latvia, Republic of
#
#
#             -----
#             Changing
#
#             Original: Lithuania
#             New: Lithuania, Republic of
#
#
#             -----
#             Changing
#
#             Original: Luxembourg
#             New: Luxembourg, Grand Duchy of
#
#
#             -----
#             Changing
#
#             Original: Poland
#             New: Poland, Republic of
#
#
#             -----
#             Changing
#
#             Original: Slovakia
#             New: Slovakia (Slovak Republic)
#
#
#             -----
#             Changing
#
#             Original: Slovenia
#             New: Slovenia, Republic of
#
#
#             -----
#             Changing
#
#             Original: Russian Federation
#             New: Russian Federation
#
#
#             -----
#             Changing
#
#             Original: Russian Federation
#             New: Russian Federation
#
#
#             -----
#             Changing
#
#             Original: Switzerland
#             New: Switzerland, Swiss Confederation
